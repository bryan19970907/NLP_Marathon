# %%
# !python --version
# Out:
# Python 3.6.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd './drive/My Drive/NLP/day31_32'
# Out:
# /content/drive/My Drive/NLP/day31_32

# %%
#!pip install -q -U pip
#!pip install -q numpy
#!pip install -q pandas
# !pip install -q ckiptagger[gdown]
# !pip install -q tqdm
#!pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets
#!pip install -q matplotlib

# %%
import pandas as pd
import numpy as np

from ckiptagger import data_utils, construct_dictionary, WS, POS, NER
from tqdm.notebook import tqdm

# %%
# Downloads to ./data.zip (2GB) and extracts to ./data/
# data_utils.download_data_url("./") # iis-ckip
#data_utils.download_data_gdown("./") # gdrive-ckip

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:903: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %% [markdown]
# # Bag of Words (BOW)

# %%
train_title_cuts
# Out:
# {0: [('亞洲杯', 'Nb'),
#   ('奪', 'VC'),
#   ('冠賠率', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('日本', 'Nc'),
#   ('、', 'PAUSECATEGORY'),
#   ('伊朗', 'Nc'),
#   ('領銜', 'VB'),
#   (' ', 'WHITESPACE'),
#   ('中國', 'Nc'),
#   ('竟', 'D'),
#   ('與', 'P'),
#   ('泰國', 'Nc'),
#   ('並列', 'VG')],
#  1: [('9', 'Neu'),
#   ('輪', 'Nf'),
#   ('4', 'Neu'),
#   ('球', 'Na'),
#   ('本土', 'Nc'),
#   ('射手', 'Na'),
#   ('僅次', 'VJ'),
#   ('武磊', 'Nb'),
#   (' ', 'WHITESPACE'),
#   ('黃紫昌', 'Nb'),
#   ('要', 'D'),
#   ('搶', 'VD'),
#   ('最', 'Dfa'),
#   ('強', 'VH'),
#   ('U23', 'Nb'),
#   ('頭銜', 'Na')],
#  2: [('如果', 'Cbb'),
#   ('今年', 'Nd'),
#   ('勇士', 'Na'),
#   ('奪冠', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('下', 'Nes'),
#   ('賽', 'Na'),
#   ('季', 'Nd'),
#   ('詹姆斯', 'Nb'),
#   ('何去何從', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  3: [('超級', 'D'),
#   ('替補', 'VC'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('科斯塔', 'Nb'),
#   ('本', 'Nes'),
#   ('賽季', 'Na'),
#   ('替補', 'VC'),
#   ('出場', 'VA'),
#   ('貢獻', 'VC'),
#   ('7', 'Neu'),
#   ('次', 'Nf'),
#   ('助攻', 'VA')],
#  4: [('騎士', 'Na'),
#   ('6', 'Neu'),
#   ('天里', 'Na'),
#   ('發生', 'VJ'),
#   ('了', 'Di'),
#   ('啥', 'Nep'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('從', 'P'),
#   ('首', 'Nes'),
#   ('輪', 'Nf'),
#   ('搶', 'VD'),
#   ('七', 'Neu'),
#   ('到', 'Caa'),
#   ('次輪', 'VH'),
#   ('3-0', 'Neu'),
#   ('猛龍', 'Na')],
#  5: [('如果', 'Cbb'),
#   ('朗多', 'Nb'),
#   ('進入', 'VCL'),
#   ('轉會', 'VA'),
#   ('市場', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('哪些', 'Neqa'),
#   ('球隊', 'Na'),
#   ('適合', 'VH'),
#   ('他', 'Nh'),
#   ('？', 'QUESTIONCATEGORY')],
#  6: [('詹姆斯', 'Nb'),
#   ('G3', 'FW'),
#   ('決殺', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  7: [('大', 'VH'),
#   ('魔王', 'Na'),
#   ('帶頭', 'D'),
#   ('唱歌', 'VA'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('火箭', 'Na'),
#   ('這', 'Nep'),
#   ('像是', 'SHI'),
#   ('打', 'VC'),
#   ('季後賽', 'Na'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('爵士', 'Na'),
#   ('神帥', 'Nb'),
#   ('這', 'Nep'),
#   ('話', 'Na'),
#   ('已', 'D'),
#   ('提前', 'VB'),
#   ('投降', 'VA'),
#   ('了', 'Di')],
#  8: [('馬夏爾', 'Nb'),
#   ('要', 'D'),
#   ('去', 'VCL'),
#   ('切爾西', 'Nc'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('可以', 'D'),
#   ('商量', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('不過', 'Cbb'),
#   ('穆里尼奧', 'Nb'),
#   ('的', 'DE'),
#   ('要價', 'VJ'),
#   ('是', 'SHI'),
#   ('4000萬', 'Neu'),
#   ('加威廉', 'Nb')],
#  9: [('利希', 'Nc'),
#   ('施泰納', 'Nb'),
#   ('宣佈', 'VE'),
#   ('賽季', 'Na'),
#   ('結束', 'VHC'),
#   ('後', 'Ng'),
#   ('離隊', 'VA'),
#   ('：', 'COLONCATEGORY'),
#   ('我', 'Nh'),
#   ('需要', 'VK'),
#   ('新', 'VH'),
#   ('的', 'DE'),
#   ('挑戰', 'Na')],
#  10: [('怎麼樣', 'VH'),
#   ('看待', 'VC'),
#   ('大連', 'Nc'),
#   ('一方', 'Nh'),
#   ('在', 'P'),
#   ('中', 'Ncd'),
#   ('超聯賽', 'Na'),
#   ('第九', 'Neu'),
#   ('輪', 'Nf'),
#   ('取得', 'VC'),
#   ('的', 'DE'),
#   ('賽季', 'Na'),
#   ('首', 'D'),
#   ('勝', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  11: [('科勒·卡戴珊', 'Nb'),
#   ('與', 'Caa'),
#   ('男友', 'Na'),
#   ('TT', 'FW'),
#   ('共進', 'VC'),
#   ('午餐', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('曾', 'D'),
#   ('在', 'P'),
#   ('他', 'Nh'),
#   ('懷孕', 'VA'),
#   ('期間', 'Na'),
#   ('偷腥', 'VA'),
#   ('的', 'DE'),
#   ('渣男', 'Na'),
#   ('被', 'P'),
#   ('原', 'A')],
#  12: [('作為', 'VG'),
#   ('央視', 'Nc'),
#   ('體育', 'Na'),
#   ('體育', 'Na'),
#   ('頻道', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('CCTV5', 'FW'),
#   ('一', 'D'),
#   ('到', 'Caa'),
#   ('週末', 'Nd'),
#   ('就', 'D'),
#   ('直播', 'VC'),
#   ('馬拉松', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  13: [('如果', 'Cbb'),
#   ('2018', 'Nd'),
#   ('騎士', 'Na'),
#   ('奪冠', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('這', 'Nep'),
#   ('個', 'Nf'),
#   ('冠軍', 'Na'),
#   ('的', 'DE'),
#   ('含金量', 'Na'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('大', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  14: [('昔日', 'Nd'),
#   ('中', 'Ng'),
#   ('超', 'VJ'),
#   ('金靴', 'Na'),
#   ('半', 'Neqa'),
#   ('場', 'Nf'),
#   ('獨造', 'VC'),
#   ('6', 'Neu'),
#   ('球', 'Na'),
#   ('虐爆', 'VC'),
#   ('遼足', 'Nb'),
#   (' ', 'WHITESPACE'),
#   ('華夏', 'Nc'),
#   ('送走', 'VC'),
#   ('他', 'Nh'),
#   ('後悔', 'VL'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  15: [('NBA', 'Nb'),
#   ('歷史', 'Na'),
#   ('排名', 'VG'),
#   ('前', 'Nes'),
#   ('十', 'Neu'),
#   ('都', 'D'),
#   ('有', 'V_2'),
#   ('誰', 'Nh'),
#   ('？', 'QUESTIONCATEGORY')],
#  16: [('你', 'Nh'),
#   ('希望', 'VK'),
#   ('利物浦', 'Nc'),
#   ('贏得', 'VJ'),
#   ('歐冠', 'Na'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('巴薩', 'Nb'),
#   ('主帥', 'Na'),
#   ('巴爾韋德', 'Nb'),
#   ('的', 'DE'),
#   ('回答', 'Na'),
#   ('耐人尋味', 'VH')],
#  17: [('絕殺', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('38', 'Neu'),
#   ('+7', 'FW'),
#   ('再', 'D'),
#   ('創', 'VC'),
#   ('傳奇', 'Na'),
#   ('一', 'Neu'),
#   ('刻', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('兩護法', 'Na'),
#   ('創', 'VC'),
#   ('另類', 'VH'),
#   ('神跡', 'Na'),
#   ('更', 'Dfa'),
#   ('功不可', 'VH'),
#   ('沒', 'D')],
#  18: [('再現', 'VH'),
#   ('絕殺', 'VA'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('今天', 'Nd'),
#   ('的', 'DE'),
#   ('老詹', 'Nb'),
#   ('怎麼', 'D'),
#   ('吹', 'VC')],
#  19: [('拜仁', 'Nb'),
#   ('3', 'Neu'),
#   ('比', 'Caa'),
#   ('1', 'Neu'),
#   ('逆轉', 'VA'),
#   ('科隆', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('J', 'FW'),
#   ('羅現', 'Nb'),
#   ('世界級', 'Na'),
#   ('做', 'VC'),
#   ('餅', 'Na')],
#  20: [('白送', 'VD'),
#   ('一', 'Neu'),
#   ('個', 'Nf'),
#   ('點球', 'VA'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('恆', 'D'),
#   ('大都', 'D'),
#   ('不', 'D'),
#   ('要', 'VC'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('卡納瓦羅', 'Nb'),
#   ('笑容', 'Na'),
#   ('真', 'D'),
#   ('有意思', 'VH')],
#  21: [('劉詩雯', 'Nb'),
#   ('戴罪', 'VA'),
#   ('立功', 'VA'),
#   ('取勝', 'VI'),
#   ('平野', 'Na'),
#   ('美宇', 'Nb'),
#   ('為', 'P'),
#   ('中國', 'Nc'),
#   ('女乒', 'Na'),
#   ('拿到', 'VC'),
#   ('世乒賽', 'Na'),
#   ('冠軍', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('怎麼', 'D'),
#   ('看待', 'VC'),
#   ('這', 'Nep'),
#   ('場', 'Nf'),
#   ('比賽', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  22: [('天堂', 'Nc'),
#   ('與', 'Caa'),
#   ('地獄', 'Nc'),
#   ('是', 'SHI'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('近', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('看看', 'VE'),
#   ('比賽', 'Na'),
#   ('最後', 'Nd'),
#   ('8', 'Neu'),
#   ('秒', 'Nf'),
#   ('的', 'DE'),
#   ('猛龍', 'Na'),
#   ('就', 'D'),
#   ('知道', 'VK'),
#   ('了', 'T')],
#  23: [('魯能', 'Nb'), ('隊員', 'Na'), ('的', 'DE'), ('身高', 'Na')],
#  24: [('WKG&M-1世界', 'Nc'),
#   ('綜合', 'A'),
#   ('格鬥賽', 'Na'),
#   ('明星', 'Na'),
#   ('見面', 'VA'),
#   ('會', 'D'),
#   ('引爆', 'VC'),
#   ('鵬城', 'Nc')],
#  25: [('如何', 'D'),
#   ('看待', 'VC'),
#   ('第一', 'Neu'),
#   ('詹黑皮爾斯', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('公開', 'VHC'),
#   ('贊美', 'VC'),
#   ('詹姆斯', 'Nb'),
#   ('？', 'QUESTIONCATEGORY')],
#  26: [('粵媒', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('缺少', 'VJ'),
#   ('外援', 'Na'),
#   ('的', 'DE'),
#   ('恆大', 'Nb'),
#   ('還是', 'D'),
#   ('不行', 'VH')],
#  27: [('熱刺作死', 'VH'),
#   ('的', 'DE'),
#   ('節奏', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('連', 'Cbb'),
#   ('墊底隊', 'Na'),
#   ('都', 'D'),
#   ('輸', 'VD'),
#   ('，', 'COMMACATEGORY'),
#   ('歐冠席', 'Na'),
#   ('位懸', 'Na'),
#   ('了', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  28: [('德帥', 'Nb'),
#   ('談', 'VE'),
#   ('沒', 'VJ'),
#   ('球隊', 'Na'),
#   ('面試', 'VC'),
#   ('布茲德里克', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('出於', 'VJ'),
#   ('自私', 'VH'),
#   ('的', 'DE'),
#   ('原因', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('他', 'Nh'),
#   ('在', 'P'),
#   ('這', 'Nep'),
#   ('讓', 'VL'),
#   ('我', 'Nh'),
#   ('開心', 'VH')],
#  29: [('雙刃劍', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('山東', 'Nc'),
#   ('魯能', 'Nb'),
#   ('高中鋒', 'Na'),
#   ('讓', 'VL'),
#   ('人', 'Na'),
#   ('又', 'Caa'),
#   ('愛', 'VL'),
#   ('又', 'Caa'),
#   ('恨', 'VK')],
#  30: [('克洛普', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('希望', 'VK'),
#   ('凱塔', 'Nb'),
#   ('能', 'D'),
#   ('迅速', 'VH'),
#   ('起到', 'VC'),
#   ('作用', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('可能', 'D'),
#   ('會', 'D'),
#   ('邀請', 'VC'),
#   ('他', 'Nh'),
#   ('去', 'VCL'),
#   ('基輔', 'Nc')],
#  31: [('在', 'P'),
#   ('歐洲', 'Nc'),
#   ('是', 'SHI'),
#   ('奪', 'VC'),
#   ('歐冠難', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('還是', 'D'),
#   ('奪', 'VC'),
#   ('聯賽', 'Na'),
#   ('難', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('這', 'Nep'),
#   ('篇', 'Nf'),
#   ('文章', 'Na'),
#   ('將', 'D'),
#   ('告訴', 'VE'),
#   ('您', 'Nh'),
#   ('答案', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  32: [('斯諾克', 'Nb'),
#   ('世錦賽', 'Na'),
#   ('半', 'Neqa'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('馬克', 'Nb'),
#   ('-', 'DASHCATEGORY'),
#   ('威廉姆斯', 'Nb'),
#   ('17', 'Neu'),
#   ('-', 'DASHCATEGORY'),
#   ('15', 'Neu'),
#   ('霍金斯', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('希金斯', 'Nb'),
#   ('和', 'Caa'),
#   ('威廉姆斯', 'Nb'),
#   ('誰', 'Nh'),
#   ('能', 'D'),
#   ('奪冠', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  33: [('脂肪肝', 'Na'),
#   ('怎樣', 'D'),
#   ('最', 'Dfa'),
#   ('快', 'VH'),
#   ('消失', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  34: [('韋德', 'Nb'),
#   ('的', 'DE'),
#   ('一', 'Neu'),
#   ('句', 'Nf'),
#   ('bad boy', 'FW'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('網友', 'Na'),
#   ('們', 'Na'),
#   ('炸', 'VC'),
#   ('了', 'Di'),
#   ('：', 'COLONCATEGORY'),
#   ('個個', 'Neqa'),
#   ('都', 'D'),
#   ('是', 'SHI'),
#   ('段子手', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  35: [('中國隊', 'Na'),
#   ('亞洲杯', 'Nb'),
#   ('抽到', 'VC'),
#   ('上上', 'A'),
#   ('簽', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('為何', 'D'),
#   ('里皮', 'Na'),
#   ('臉色', 'Na'),
#   ('仍然', 'D'),
#   ('很', 'Dfa'),
#   ('凝重', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  36: [('今日', 'Nd'),
#   ('直播', 'VC'),
#   ('龍星戰', 'Nb'),
#   ('及', 'Caa'),
#   ('女子', 'Na'),
#   ('圍甲', 'Nb'),
#   (' + ', 'FW'),
#   ('星陣', 'Na'),
#   ('讓', 'VL'),
#   ('先', 'D'),
#   ('9', 'Neu'),
#   ('連勝', 'VH'),
#   (' + ', 'FW'),
#   ('暗渡', 'VCL'),
#   ('陳倉', 'Nc')],
#  37: [('如果', 'Cbb'),
#   ('勇士', 'Na'),
#   ('今年', 'Nd'),
#   ('奪得', 'VC'),
#   ('總冠軍', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('是', 'SHI'),
#   ('不', 'D'),
#   ('是', 'SHI'),
#   ('就算', 'Cbb'),
#   ('建立', 'VC'),
#   ('了', 'Di'),
#   ('王朝', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  38: [('橫掃', 'VCL'),
#   ('東部', 'Ncd'),
#   ('第一', 'Neu'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('這', 'Nep'),
#   ('事', 'Na'),
#   ('騎士', 'Na'),
#   ('已經', 'D'),
#   ('乾', 'VH'),
#   ('過', 'Di'),
#   ('一', 'Neu'),
#   ('次', 'Nf'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('直接', 'VH'),
#   ('把', 'P'),
#   ('對手', 'Na'),
#   ('打到', 'VC'),
#   ('解體', 'VB'),
#   ('重建', 'VC'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  39: [('2018', 'Nd'),
#   ('陸家嘴', 'Nc'),
#   ('金融城', 'Nc'),
#   ('足球', 'Na'),
#   ('聯賽', 'Na'),
#   ('昨天', 'Nd'),
#   ('拉開', 'VC'),
#   ('帷幕', 'Na')],
#  40: [('絕殺', 'VC'),
#   ('猛龍', 'Na'),
#   ('之', 'DE'),
#   ('夜', 'Nd'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('5', 'Neu'),
#   ('次', 'Nf'),
#   ('重', 'VH'),
#   ('摔', 'VC'),
#   ('在', 'P'),
#   ('地', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('再', 'D'),
#   ('心酸', 'VH'),
#   ('也', 'D'),
#   ('值得', 'VH'),
#   ('了', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  41: [('哦', 'I'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('中國', 'Nc'),
#   ('第114', 'Neu'),
#   ('個', 'Nf'),
#   ('世界', 'Nc'),
#   ('乒乓球', 'Na'),
#   ('冠軍', 'Na'),
#   ('—', 'DASHCATEGORY'),
#   ('—', 'DASHCATEGORY'),
#   ('王楚欽', 'Nb'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('為', 'P'),
#   ('中國', 'Nc'),
#   ('對', 'P'),
#   ('加油', 'VB'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  42: [('朱婷', 'Nb'),
#   ('在', 'P'),
#   ('女排', 'Na'),
#   ('歐冠', 'Na'),
#   ('半', 'Neqa'),
#   ('決賽', 'Na'),
#   ('中', 'Ng'),
#   ('受傷', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('會', 'D'),
#   ('對', 'P'),
#   ('瓦基弗', 'Nb'),
#   ('產生', 'VHC'),
#   ('怎樣', 'VH'),
#   ('的', 'DE'),
#   ('影響', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('還', 'D'),
#   ('能夠', 'D'),
#   ('奪冠', 'VA'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  43: [('德國', 'Nc'),
#   ('男乒', 'Na'),
#   ('3:2', 'Neu'),
#   ('艱難', 'VH'),
#   ('戰勝', 'VC'),
#   ('韓國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('挺進', 'VA'),
#   ('決賽', 'Na'),
#   ('會師', 'VA'),
#   ('國乒', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('中', 'Nc'),
#   ('德', 'Nc'),
#   ('乒乓', 'A'),
#   ('大戰', 'Na'),
#   ('勝算', 'Na'),
#   ('大', 'VH'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  44: [('詹姆斯', 'Nb'),
#   ('現在', 'Nd'),
#   ('的', 'DE'),
#   ('絕殺球', 'Na'),
#   ('能力', 'Na'),
#   ('在', 'P'),
#   ('聯盟', 'Na'),
#   ('中', 'Ng'),
#   ('是', 'SHI'),
#   ('什麼', 'Nep'),
#   ('水準', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  45: [('淘汰', 'VC'),
#   ('恆大', 'Nb'),
#   ('也', 'D'),
#   ('保', 'VC'),
#   ('不', 'D'),
#   ('住', 'VC'),
#   ('曼薩諾', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('保級', 'VA'),
#   ('戰釀', 'VC'),
#   ('1', 'Neu'),
#   ('-', 'DASHCATEGORY'),
#   ('5', 'Neu'),
#   ('慘案', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('球迷', 'Na'),
#   ('怒吼', 'VA'),
#   ('下課', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  46: [('曝限', 'VJ'),
#   ('薪令', 'Na'),
#   ('最', 'Dfa'),
#   ('快', 'VH'),
#   ('在', 'P'),
#   ('夏窗', 'Nd'),
#   ('出台', 'VA'),
#   (' ', 'WHITESPACE'),
#   ('恆', 'D'),
#   ('大', 'VH'),
#   ('重慶', 'Nc'),
#   ('或', 'Caa'),
#   ('成', 'VG'),
#   ('最', 'Dfa'),
#   ('大', 'VH'),
#   ('受害', 'VH'),
#   ('者', 'Na')],
#  47: [('58', 'Neu'),
#   ('同', 'Nes'),
#   ('城', 'Na'),
#   ('中甲', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('下', 'Nes'),
#   ('半', 'Neqa'),
#   ('場', 'Nf'),
#   ('的', 'DE'),
#   ('卓爾', 'Nb'),
#   ('惹不起', 'VJ'),
#   (' ', 'WHITESPACE'),
#   ('他們', 'Nh'),
#   ('這', 'Nep'),
#   ('一', 'Neu'),
#   ('數據', 'Na'),
#   ('冠絕', 'VC'),
#   ('聯賽', 'Na')],
#  48: [('瑞典', 'Nc'),
#   ('世乒賽', 'Na'),
#   ('中國', 'Nc'),
#   ('女隊', 'Na'),
#   ('奪冠', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('如何', 'D'),
#   ('看待', 'VC'),
#   ('新聞', 'Na'),
#   ('發佈會', 'Na'),
#   ('上', 'Ng'),
#   ('石川佳純', 'Nb'),
#   ('充當', 'VG'),
#   ('中國', 'Nc'),
#   ('翻譯', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  49: [('世乒賽', 'Na'),
#   ('男團', 'Na'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('中國隊', 'Na'),
#   ('3-0', 'Neu'),
#   ('完勝', 'VH'),
#   ('德國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('兩', 'Neu'),
#   ('隊', 'Nf'),
#   ('的', 'DE'),
#   ('排兵', 'VA'),
#   ('布陣', 'Na'),
#   ('有', 'V_2'),
#   ('哪些', 'Neqa'),
#   ('亮點', 'Na'),
#   ('和', 'Caa'),
#   ('失誤', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  50: [('道義', 'Na'),
#   ('放', 'VC'),
#   ('兩旁', 'Ncd'),
#   ('利', 'VH'),
#   ('字', 'Na'),
#   ('擺', 'VC'),
#   ('中間', 'Ncd'),
#   ('，', 'COMMACATEGORY'),
#   ('屢', 'D'),
#   ('戰', 'VA'),
#   ('屢', 'D'),
#   ('敗', 'VH'),
#   ('的', 'DE'),
#   ('曼薩諾', 'Nb'),
#   ('還', 'D'),
#   ('能', 'D'),
#   ('走', 'VA'),
#   ('多', 'Dfa'),
#   ('遠', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  51: [('如果', 'Cbb'),
#   ('騎士', 'Na'),
#   ('今年', 'Nd'),
#   ('一', 'Neu'),
#   ('輪', 'Nf'),
#   ('游', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('那麼', 'Dk'),
#   ('詹姆斯', 'Nb'),
#   ('的', 'DE'),
#   ('歷史', 'Na'),
#   ('地位', 'Na'),
#   ('會', 'D'),
#   ('受', 'P'),
#   ('影響', 'VC'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('他', 'Nh'),
#   ('還', 'D'),
#   ('有', 'V_2'),
#   ('機會', 'Na'),
#   ('再', 'D'),
#   ('進', 'VCL'),
#   ('總決賽', 'Na'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  52: [('通過', 'VC'),
#   ('運動', 'Na'),
#   ('健身', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('覺得', 'VK'),
#   ('對', 'P'),
#   ('你', 'Nh'),
#   ('最', 'Dfa'),
#   ('大', 'VH'),
#   ('的', 'DE'),
#   ('改變', 'VC'),
#   ('是', 'SHI'),
#   ('什麼', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  53: [('上港', 'Nb'),
#   ('主場', 'Na'),
#   ('1-2', 'Neu'),
#   ('負於', 'VJ'),
#   ('國安', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('遭遇', 'VJ'),
#   ('聯賽', 'Na'),
#   ('兩', 'Neu'),
#   ('連敗', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('上港', 'Nb'),
#   ('到底', 'D'),
#   ('輸', 'VD'),
#   ('在', 'P'),
#   ('哪', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  54: [('法網', 'Na'),
#   ('衛冕', 'VC'),
#   ('冠軍', 'Na'),
#   ('在', 'P'),
#   ('馬德里', 'Nc'),
#   ('首', 'Nes'),
#   ('輪', 'Nf'),
#   ('出局', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('法網', 'Na'),
#   ('衛冕', 'VC'),
#   ('前景', 'Na'),
#   ('蒙上', 'VC'),
#   ('陰影', 'Na')],
#  55: [('騎士', 'Na'),
#   ('和', 'Caa'),
#   ('步行', 'VA'),
#   ('者', 'Na'),
#   ('戰成', 'VG'),
#   ('搶七', 'VA'),
#   ('險勝', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('而', 'Cbb'),
#   ('猛龍', 'Na'),
#   ('即將', 'D'),
#   ('被', 'P'),
#   ('橫掃', 'VCL'),
#   ('，', 'COMMACATEGORY'),
#   ('步行', 'VA'),
#   ('者', 'Na'),
#   ('跟', 'Caa'),
#   ('猛龍', 'Na'),
#   ('的', 'DE'),
#   ('區別', 'Na'),
#   ('在', 'P'),
#   ('哪裡', 'Ncd'),
#   ('？', 'QUESTIONCATEGORY')],
#  56: [('中超', 'Nb'),
#   ('單場', 'Na'),
#   ('消息', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('埃爾克森', 'Nb'),
#   ('建功', 'VA'),
#   ('難', 'VH'),
#   ('救主', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('上港', 'Nb'),
#   ('主場', 'Na'),
#   ('遭遇', 'VJ'),
#   ('國安', 'Na'),
#   ('逆轉', 'VA')],
#  57: [('惠若琪', 'Nb'),
#   ('被', 'P'),
#   ('問', 'VE'),
#   ('女排', 'Na'),
#   ('中', 'Ng'),
#   ('素顏', 'Na'),
#   ('誰', 'Nh'),
#   ('最', 'Dfa'),
#   ('美', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('她', 'Nh'),
#   ('機智', 'VH'),
#   ('地', 'DE'),
#   ('回答', 'VE'),
#   ('郎平', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  58: [('維亞利', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('尤文', 'Nb'),
#   ('不應該', 'D'),
#   ('簽', 'VC'),
#   ('埃姆雷', 'Nb'),
#   ('-', 'DASHCATEGORY'),
#   ('詹', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('而', 'Cbb'),
#   ('該', 'D'),
#   ('選', 'VC'),
#   ('拉基蒂奇', 'Nb')],
#  59: [('大連', 'Nc'),
#   ('一方', 'Nh'),
#   ('3:0', 'Neu'),
#   ('完勝', 'VH'),
#   ('恆大', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('足協杯', 'Nb'),
#   ('出局', 'VH'),
#   ('、', 'PAUSECATEGORY'),
#   ('又', 'D'),
#   ('被', 'P'),
#   ('一', 'Neu'),
#   ('方', 'Nf'),
#   ('大敗', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('恆大', 'Nb'),
#   ('怎麼', 'VH'),
#   ('了', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  60: [('19年', 'Nd'),
#   ('亞洲杯', 'Nb'),
#   ('國足', 'Na'),
#   ('所在', 'Na'),
#   ('的', 'DE'),
#   ('C組', 'Na'),
#   ('算是', 'VG'),
#   ('上上', 'A'),
#   ('簽', 'VC'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  61: [('安德森', 'Nb'),
#   ('數據', 'Na'),
#   ('依舊', 'D'),
#   ('犀利', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('對比', 'Na'),
#   ('之後', 'Ng'),
#   ('並', 'D'),
#   ('沒有', 'VJ'),
#   ('變化', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('德安東尼', 'Nb'),
#   ('在', 'P'),
#   ('下', 'Nes'),
#   ('一', 'Neu'),
#   ('盤', 'Nf'),
#   ('大', 'VH'),
#   ('棋', 'Na')],
#  62: [('勒布朗', 'Nb'),
#   ('已', 'D'),
#   ('是', 'SHI'),
#   ('美國', 'Nc'),
#   ('各', 'Nes'),
#   ('大', 'VH'),
#   ('媒體', 'Na'),
#   ('公認', 'VE'),
#   ('的', 'DE'),
#   ('歷史', 'Na'),
#   ('第二', 'Neu'),
#   ('人', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('他', 'Nh'),
#   ('與', 'P'),
#   ('喬丹', 'Nb'),
#   ('的', 'DE'),
#   ('差距', 'Na'),
#   ('究竟', 'D'),
#   ('還', 'D'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('大', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  63: [('騎士', 'Na'),
#   ('戰勝', 'VC'),
#   ('猛龍', 'Na'),
#   ('拿到', 'VC'),
#   ('賽點', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('此', 'Nep'),
#   ('項', 'Nf'),
#   ('數據', 'Na'),
#   ('NBA', 'Nb'),
#   ('第一', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('超過', 'VJ'),
#   ('喬丹', 'Nb')],
#  64: [('凱西', 'Nb'),
#   ('談', 'VE'),
#   ('德羅贊', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('投', 'VC'),
#   ('不', 'D'),
#   ('好', 'VC'),
#   ('也', 'D'),
#   ('可以', 'D'),
#   ('做', 'VC'),
#   ('其它', 'Neqa'),
#   ('事', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('比如', 'P'),
#   ('防守', 'VC')],
#  65: [('24', 'Neu'),
#   ('+', 'FW'),
#   ('5', 'Neu'),
#   ('+4', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('第一', 'Neu'),
#   ('新秀', 'Na'),
#   ('換人', 'VA'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('20', 'Neu'),
#   ('歲', 'Nf'),
#   ('天才', 'Na'),
#   ('刷爆', 'VC'),
#   ('72', 'Neu'),
#   ('年', 'Nf'),
#   ('歷史', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('小詹皇', 'Nb'),
#   ('被', 'P'),
#   ('他', 'Nh'),
#   ('打爆', 'VC')],
#  66: [('人', 'Na'),
#   ('和', 'Caa'),
#   ('逼', 'VF'),
#   ('平魯能', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('京城', 'Nc'),
#   ('狂漲粉', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('北京', 'Nc'),
#   ('國安', 'Na'),
#   ('下輪', 'Na'),
#   ('有望', 'VH'),
#   ('登頂', 'VC'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  67: [('瓦基弗', 'Nb'),
#   ('銀行', 'Nc'),
#   ('3:2', 'Neu'),
#   ('逆轉', 'VA'),
#   ('意大利', 'Nc'),
#   ('冠軍', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('晉級', 'VJ'),
#   ('歐冠', 'Na'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('距離', 'P'),
#   ('全滿貫', 'Na'),
#   ('又', 'D'),
#   ('近', 'VJ'),
#   ('了', 'Di'),
#   ('一', 'Neu'),
#   ('步', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  68: [('中超', 'Nb'),
#   ('第九', 'Neu'),
#   ('輪', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('山東', 'Nc'),
#   ('魯能', 'Nb'),
#   ('0:0', 'Neu'),
#   ('戰平', 'VH'),
#   ('北京人和', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('錯失', 'VJ'),
#   ('登頂', 'VC'),
#   ('良機', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('怎麼', 'D'),
#   ('評價', 'VC'),
#   ('本', 'Nes'),
#   ('場', 'Nf'),
#   ('比賽', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  69: [('為什麼', 'D'),
#   ('提起', 'VE'),
#   ('火箭隊', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('很多', 'Neqa'),
#   ('球迷', 'Na'),
#   ('就', 'D'),
#   ('會', 'D'),
#   ('想起', 'VE'),
#   ('奧拉朱旺', 'Nb'),
#   ('？', 'QUESTIONCATEGORY')],
#  70: [('世乒賽', 'Na'),
#   ('奪冠', 'VA'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('劉詩雯', 'Nb'),
#   ('調侃', 'VC'),
#   ('自己', 'Nh'),
#   ('在', 'P'),
#   ('職業', 'Na'),
#   ('生涯', 'Na'),
#   ('末端', 'Ncd'),
#   ('，', 'COMMACATEGORY'),
#   ('兩', 'Neu'),
#   ('年', 'Nf'),
#   ('後', 'Ng'),
#   ('奧運會', 'Na'),
#   ('還', 'D'),
#   ('能', 'D'),
#   ('見到', 'VE'),
#   ('小棗', 'Na'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  71: [('2018年', 'Nd'),
#   ('俄羅斯', 'Nc'),
#   ('世界杯', 'Nb'),
#   ('12', 'Neu'),
#   ('座', 'Nf'),
#   ('球館', 'Nc'),
#   ('巡禮', 'VA'),
#   ('—', 'DASHCATEGORY'),
#   ('—', 'DASHCATEGORY'),
#   ('伏爾加格勒', 'Nb'),
#   ('體育場', 'Nc')],
#  72: [('詹皇', 'Nb'),
#   ('絕殺', 'VH'),
#   ('樂福', 'Nb'),
#   ('21', 'Neu'),
#   ('+', 'FW'),
#   ('16', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('騎士', 'Na'),
#   ('險勝', 'VH'),
#   ('猛龍', 'Na'),
#   ('總', 'D'),
#   ('比', 'P'),
#   ('分', 'VC'),
#   ('3', 'Neu'),
#   ('-', 'DASHCATEGORY'),
#   ('0', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  73: [('聯賽', 'Na'),
#   ('8', 'Neu'),
#   ('輪', 'Nf'),
#   ('不', 'D'),
#   ('敗', 'VH'),
#   ('+', 'FW'),
#   ('斬落', 'VC'),
#   ('領頭', 'VA'),
#   ('羊', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('國安', 'Na'),
#   ('攪亂', 'VC'),
#   ('中', 'Ng'),
#   ('超爭', 'VC'),
#   ('冠格局', 'Nc')],
#  74: [('2019', 'Nd'),
#   ('亞洲杯', 'Nb'),
#   ('中國', 'Nc'),
#   ('國足', 'Na'),
#   ('到底', 'D'),
#   ('怎樣', 'D'),
#   ('做', 'VC'),
#   ('才', 'Da'),
#   ('能', 'D'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('奪冠', 'VA'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('？', 'QUESTIONCATEGORY')],
#  75: [('一', 'Neu'),
#   ('水', 'Na'),
#   ('二', 'Neu'),
#   ('浪', 'Na'),
#   ('三', 'Neu'),
#   ('死神', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('濃眉', 'Na'),
#   ('做', 'VC'),
#   ('花迪', 'Na'),
#   ('做', 'VC'),
#   ('葉', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('橫批', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  76: [('傑森', 'Nb'),
#   ('-', 'DASHCATEGORY'),
#   ('特里', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('塔特姆', 'Nb'),
#   ('打出', 'VC'),
#   ('了', 'Di'),
#   ('超過', 'VJ'),
#   ('他', 'Nh'),
#   ('年齡', 'Na'),
#   ('的', 'DE'),
#   ('極', 'Dfa'),
#   ('佳', 'VH'),
#   ('表現', 'VC')],
#  77: [('多點', 'Neqa'),
#   ('開花', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('國際', 'Nc'),
#   ('米蘭', 'Nc'),
#   ('客場', 'Na'),
#   ('大勝', 'VJ'),
#   ('烏迪內斯', 'Nb')],
#  78: [('生猛', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('這', 'Nep'),
#   ('個', 'Nf'),
#   ('女人', 'Na'),
#   ('當', 'VG'),
#   ('4', 'Neu'),
#   ('年', 'Nf'),
#   ('馬刺', 'Nc'),
#   ('助教', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('現在', 'Nd'),
#   ('又', 'D'),
#   ('要', 'D'),
#   ('去', 'D'),
#   ('應聘', 'VG'),
#   ('主教練', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  79: [('離', 'P'),
#   ('被', 'P'),
#   ('橫掃', 'VCL'),
#   ('不遠', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('猛龍', 'Na'),
#   ('系列賽', 'Na'),
#   ('6', 'Neu'),
#   ('困擾', 'Na'),
#   ('難', 'VH'),
#   ('解決', 'VC'),
#   ('：', 'COLONCATEGORY'),
#   ('1', 'Neu'),
#   ('優勢', 'Na'),
#   ('騎士', 'Na'),
#   ('輕鬆', 'VH'),
#   ('破除', 'VC')],
#  80: [('四國', 'Nc'),
#   ('青年', 'Na'),
#   ('女籃', 'Na'),
#   ('亞特拉斯賽', 'Nb'),
#   ('在', 'P'),
#   ('秀', 'Na'),
#   ('舉行', 'VC')],
#  81: [('史蒂文斯', 'Nb'),
#   ('神奇', 'VH'),
#   ('調整', 'VC'),
#   ('凱爾特', 'Nb'),
#   ('人', 'Na'),
#   ('加時', 'VA'),
#   ('再', 'D'),
#   ('勝', 'VH'),
#   ('76', 'Neu'),
#   ('人', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('蘇群', 'Nb'),
#   ('：76', 'Neu'),
#   ('人', 'Na'),
#   ('完', 'VH'),
#   ('了', 'T')],
#  82: [('大連海', 'Nc'),
#   ('那麼多', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('都', 'D'),
#   ('有', 'V_2'),
#   ('什麼', 'Nep'),
#   ('海', 'Na'),
#   ('上', 'Ncd'),
#   ('遊樂', 'Nv'),
#   ('項目', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  83: [('德羅贊', 'Nb'),
#   ('連續', 'VH'),
#   ('13', 'Neu'),
#   ('場', 'Nf'),
#   ('季後賽', 'Na'),
#   ('面對', 'VC'),
#   ('騎士', 'Na'),
#   ('沒有', 'D'),
#   ('投進', 'VC'),
#   ('三', 'Neu'),
#   ('分', 'Nf')],
#  84: [('亞洲杯', 'Nb'),
#   ('分組', 'VB'),
#   ('國足', 'Na'),
#   ('抽', 'VC'),
#   ('得', 'DE'),
#   ('上', 'VC'),
#   ('上', 'Ncd'),
#   ('簽', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('國足', 'Na'),
#   ('就', 'D'),
#   ('一定', 'D'),
#   ('能', 'D'),
#   ('出線', 'VH'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  85: [('撒', 'VC'),
#   ('彩紙', 'Na'),
#   ('也', 'D'),
#   ('不', 'D'),
#   ('看清楚', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('打掃', 'VC'),
#   ('了', 'Di'),
#   ('足足', 'Da'),
#   ('七', 'Neu'),
#   ('分鐘', 'Nf'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('凱爾特人', 'Na'),
#   ('竊喜', 'VH'),
#   ('中', 'Ng'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  86: [('時間', 'Na'),
#   ('過去', 'Nd'),
#   ('將近', 'Da'),
#   ('兩', 'Neu'),
#   ('年', 'Nf'),
#   ('了', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('大家', 'Nh'),
#   ('是', 'SHI'),
#   ('如何', 'D'),
#   ('看待', 'VC'),
#   ('杜蘭特', 'Nb'),
#   ('加盟', 'VC'),
#   ('勇士', 'Na'),
#   ('這', 'Nep'),
#   ('件', 'Nf'),
#   ('事情', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  87: [('卡拉斯科', 'Nb'),
#   ('的', 'DE'),
#   ('底線', 'Na'),
#   ('過人', 'VH'),
#   ('和', 'Caa'),
#   ('本澤馬', 'Nb'),
#   ('的', 'DE'),
#   ('哪', 'Nep'),
#   ('個', 'Nf'),
#   ('更', 'Dfa'),
#   ('優秀', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  88: [('NBA', 'Nb'),
#   ('如果', 'Cbb'),
#   ('用', 'P'),
#   ('帶隊', 'VA'),
#   ('能力', 'Na'),
#   ('給', 'VD'),
#   ('現役', 'A'),
#   ('球星', 'Na'),
#   ('排名', 'VG'),
#   ('，', 'COMMACATEGORY'),
#   ('前', 'Nes'),
#   ('五', 'Neu'),
#   ('都', 'D'),
#   ('有', 'V_2'),
#   ('誰', 'Nh'),
#   ('？', 'QUESTIONCATEGORY')],
#  89: [('延邊', 'Nc'),
#   ('富德', 'Nb'),
#   ('怎麼', 'VH'),
#   ('了', 'T'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('主帥', 'Na'),
#   ('樸泰夏', 'Nb'),
#   ('怎麼', 'VH'),
#   ('了', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  90: [('米體', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('比格利亞', 'Nb'),
#   ('將', 'D'),
#   ('在', 'P'),
#   ('意大利杯', 'Nb'),
#   ('決賽', 'Na'),
#   ('中', 'Ng'),
#   ('復出', 'VH')],
#  91: [('男乒', 'Nb'), ('世乒賽', 'Na'), ('九', 'Neu'), ('連冠', 'VA')],
#  92: [('郭躍', 'Nb'),
#   ('在', 'P'),
#   ('社交', 'Na'),
#   ('平台', 'Na'),
#   ('上', 'Ng'),
#   ('說', 'VE'),
#   ('丁寧', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('每', 'Nes'),
#   ('次', 'Nf'),
#   ('輸掉', 'VJ'),
#   ('比賽', 'Na'),
#   ('都', 'D'),
#   ('說', 'VE'),
#   ('受傷', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('對', 'P'),
#   ('此', 'Nep'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  93: [('猛', 'Nb'),
#   ('龍主', 'Na'),
#   ('教練', 'Na'),
#   ('跟', 'Caa'),
#   ('泰倫盧', 'Nb'),
#   ('在', 'P'),
#   ('這', 'Nep'),
#   ('個', 'Nf'),
#   ('系列賽', 'Na'),
#   ('的', 'DE'),
#   ('執教', 'VB'),
#   ('水平', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  94: [('5', 'Neu'),
#   ('戰', 'Na'),
#   ('115', 'Neu'),
#   ('分', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('隔扣', 'VC'),
#   ('被', 'P'),
#   ('犯規', 'VA'),
#   ('還', 'D'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('口', 'Na'),
#   ('出', 'VC'),
#   ('狂言', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('，', 'COMMACATEGORY'),
#   ('球迷', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('聽', 'VE'),
#   ('這', 'Nep'),
#   ('話', 'Na'),
#   ('就', 'D'),
#   ('有', 'V_2'),
#   ('巨星', 'Na'),
#   ('潛質', 'Na')],
#  95: [('你們', 'Nh'),
#   ('覺得', 'VK'),
#   ('李秋平', 'Nb'),
#   ('加盟', 'VC'),
#   ('山東隊', 'Nb'),
#   ('的', 'DE'),
#   ('可能性', 'Na'),
#   ('大', 'VH'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  96: [('亞洲杯', 'Nb'),
#   ('小組賽', 'Na'),
#   ('中國隊', 'Na'),
#   ('賽程', 'Na'),
#   ('出爐', 'VH'),
#   ('：', 'COLONCATEGORY'),
#   ('首', 'Nes'),
#   ('戰', 'Na'),
#   ('吉爾吉斯斯坦', 'Nc')],
#  97: [('cba', 'FW'),
#   ('歷史', 'Na'),
#   ('上', 'Ng'),
#   ('最', 'Dfa'),
#   ('差', 'VH'),
#   ('的', 'DE'),
#   ('小', 'VH'),
#   ('外援', 'Na'),
#   ('是', 'SHI'),
#   ('誰', 'Nh'),
#   ('？', 'QUESTIONCATEGORY')],
#  98: [('姚明', 'Nb'),
#   ('的', 'DE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('奧運', 'Nb'),
#   ('第四', 'Neu'),
#   ('問', 'Nv'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('：', 'COLONCATEGORY'),
#   ('盼', 'VK'),
#   ('00', 'Neu'),
#   ('後', 'Ng'),
#   ('運動員', 'Na'),
#   ('繼續', 'VF'),
#   ('為', 'P'),
#   ('國旗', 'Na'),
#   ('奮鬥', 'VA')],
#  99: [('女排', 'Na'),
#   ('歐冠', 'Na'),
#   ('半', 'Neqa'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('瓦基弗', 'Nb'),
#   ('銀行', 'Nc'),
#   ('3:2', 'Neu'),
#   ('險勝', 'VH'),
#   ('科內利亞諾', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  100: [('山東', 'Nc'),
#   ('魯能', 'Nb'),
#   ('有沒有', 'D'),
#   ('可能', 'D'),
#   ('拿到', 'VC'),
#   ('今年', 'Nd'),
#   ('的', 'DE'),
#   ('中', 'A'),
#   ('超', 'A'),
#   ('冠軍', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  101: [('世乒賽', 'Na'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('劉詩雯', 'Nb'),
#   ('2:3', 'Neu'),
#   ('不敵', 'VJ'),
#   ('伊藤美誠', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('對', 'P'),
#   ('此', 'Nep'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  102: [('為何', 'D'),
#   ('看到', 'VE'),
#   ('2018', 'Neu'),
#   ('NBA', 'Nb'),
#   ('季後賽', 'Na'),
#   ('勇士', 'Na'),
#   ('VS', 'Caa'),
#   ('鵜鶘', 'Na'),
#   ('G3', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('勇士', 'Na'),
#   ('球迷', 'Na'),
#   ('稱', 'VG'),
#   ('勇士', 'Na'),
#   ('是', 'SHI'),
#   ('在', 'D'),
#   ('放水', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  103: [('WWE', 'Nb'),
#   ('巨星', 'Na'),
#   ('究竟', 'D'),
#   ('多', 'Dfa'),
#   ('有錢', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('約翰塞納', 'Nb'),
#   ('有', 'V_2'),
#   ('私人', 'Nh'),
#   ('車庫', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('比', 'P'),
#   ('WWE', 'Nb'),
#   ('老闆', 'Na'),
#   ('的', 'DE'),
#   ('車', 'Na'),
#   ('還', 'Dfa'),
#   ('多', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  104: [('大連', 'Nc'),
#   ('一方', 'Nh'),
#   ('主場', 'Na'),
#   ('3-0', 'Neu'),
#   ('擊敗', 'VC'),
#   ('廣州', 'Nc'),
#   ('恆大', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('取得', 'VC'),
#   ('中超', 'Nb'),
#   ('首', 'Nes'),
#   ('勝', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('他們', 'Nh'),
#   ('取得', 'VC'),
#   ('勝利', 'VH'),
#   ('的', 'DE'),
#   ('原因', 'Na'),
#   ('是', 'SHI'),
#   ('什麼', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  105: [('為什麼', 'D'),
#   ('國人', 'Na'),
#   ('能', 'D'),
#   ('接受', 'VC'),
#   ('並', 'Cbb'),
#   ('喜歡', 'VK'),
#   ('石川佳純', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('不', 'D'),
#   ('怎麼', 'D'),
#   ('喜歡', 'VK'),
#   ('張本智和', 'Nb'),
#   ('？', 'QUESTIONCATEGORY')],
#  106: [('日媒', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('日乒', 'Na'),
#   ('和', 'Caa'),
#   ('中國', 'Nc'),
#   ('的', 'DE'),
#   ('差距', 'Na'),
#   ('正在', 'D'),
#   ('縮小', 'VHC')],
#  107: [('上港', 'Nb'),
#   ('1-2', 'Neu'),
#   ('輸給', 'VD'),
#   ('國安', 'Na'),
#   ('的', 'DE'),
#   ('比賽', 'Na'),
#   ('中', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('國安', 'Na'),
#   ('後衛', 'Na'),
#   ('劉歡', 'Nb'),
#   ('的', 'DE'),
#   ('手球', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('沒有', 'D'),
#   ('判罰', 'VE'),
#   ('點球', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('是', 'SHI'),
#   ('不', 'D'),
#   ('是', 'SHI'),
#   ('誤判', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  108: [('網傳', 'Nb'),
#   ('《', 'PARENTHESISCATEGORY'),
#   ('馬卡報', 'Nb'),
#   ('》', 'PARENTHESISCATEGORY'),
#   ('披露', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('內馬爾', 'Nb'),
#   ('希望', 'VK'),
#   ('加盟', 'VC'),
#   ('皇馬', 'Nb'),
#   ('搭檔', 'VA'),
#   ('C', 'FW'),
#   ('羅', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('可能性', 'Na'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('大', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  109: [('德甲', 'Nb'),
#   ('官方', 'Na'),
#   ('第33', 'Neu'),
#   ('輪', 'Nf'),
#   ('最佳', 'A'),
#   ('陣容', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('J羅', 'Nb'),
#   ('入選', 'VJ'),
#   (' ', 'WHITESPACE'),
#   ('馬里奧', 'Nb'),
#   ('-', 'DASHCATEGORY'),
#   ('戈麥斯', 'Nb'),
#   ('在', 'P'),
#   ('列', 'VC')],
#  110: [('凱西', 'Nb'),
#   ('教練', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('我們', 'Nh'),
#   ('這', 'Nep'),
#   ('個', 'Nf'),
#   ('賽季', 'Na'),
#   ('已經', 'D'),
#   ('命懸', 'VC'),
#   ('一線', 'Na')],
#  111: [('武當', 'Nb'),
#   ('掌門', 'Nc'),
#   ('游玄德', 'Nb'),
#   ('在', 'P'),
#   ('生活', 'Na'),
#   ('中', 'Ng'),
#   ('。', 'PERIODCATEGORY'),
#   ('比如', 'P'),
#   ('街鬥', 'Na'),
#   ('對陣', 'VA'),
#   ('泰拳王西', 'Nb'),
#   ('提猜', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('結果', 'Dk'),
#   ('會', 'D'),
#   ('怎樣', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  112: [('猛龍', 'Na'),
#   ('慘敗', 'VH'),
#   ('騎士', 'Na'),
#   ('真', 'D'),
#   ('因', 'Cbb'),
#   ('曝光', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('兩', 'Neu'),
#   ('錯誤', 'Na'),
#   ('讓', 'VL'),
#   ('詹姆斯', 'Nb'),
#   ('上演', 'VAC'),
#   ('絕殺', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('鍋', 'Nf'),
#   ('凱西', 'Nb'),
#   ('得', 'VJ'),
#   ('背', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  113: [('魯能', 'Nb'),
#   ('0', 'Neu'),
#   ('-0', 'FW'),
#   ('客平人和', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('錯失', 'VJ'),
#   ('登頂', 'VC'),
#   ('良機', 'Na')],
#  114: [('女排', 'Na'),
#   ('國家', 'Na'),
#   ('聯賽', 'Na'),
#   ('已', 'D'),
#   ('成', 'VG'),
#   ('新人', 'Na'),
#   ('試', 'VF'),
#   ('金石', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('她', 'Nh'),
#   ('若', 'Cbb'),
#   ('能', 'D'),
#   ('把握住', 'VC'),
#   ('上位', 'Nc'),
#   ('良機', 'Na'),
#   ('必', 'D'),
#   ('成', 'VG'),
#   ('大器', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  115: [('如果', 'Cbb'),
#   ('本', 'Nes'),
#   ('賽季', 'Na'),
#   ('詹姆斯', 'Nb'),
#   ('率領', 'VF'),
#   ('騎士', 'Na'),
#   ('奪冠', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('將', 'D'),
#   ('有', 'V_2'),
#   ('怎樣', 'VH'),
#   ('的', 'DE'),
#   ('歷史', 'Na'),
#   ('地位', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  116: [('這', 'Nep'),
#   ('一', 'Neu'),
#   ('球', 'Na'),
#   ('之後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('來', 'D'),
#   ('看看', 'VE'),
#   ('各', 'Nes'),
#   ('路', 'Nf'),
#   ('球星', 'Na'),
#   ('怎麼', 'D'),
#   ('就', 'D'),
#   ('變', 'VH'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('詹吹', 'VH'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('了', 'T')],
#  117: [('爵爺', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('請', 'VF'),
#   ('你', 'Nh'),
#   ('為', 'P'),
#   ('自己', 'Nh'),
#   ('再', 'D'),
#   ('贏', 'VD'),
#   ('一', 'Neu'),
#   ('次', 'Nf'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  118: [('劉詩雯', 'Nb'),
#   ('首', 'D'),
#   ('負', 'VJ'),
#   ('日本', 'Nc'),
#   ('因', 'P'),
#   ('策略', 'Na'),
#   ('不當', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('8', 'Neu'),
#   ('年', 'Nf'),
#   ('磨礪', 'VC'),
#   ('自我', 'Nh'),
#   ('救贖', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('劉國梁', 'Nb'),
#   ('贊', 'VC'),
#   ('她', 'Nh'),
#   ('這', 'Nep'),
#   ('一', 'Neu'),
#   ('點', 'Nf')],
#  119: [('詹姆斯', 'Nb'),
#   ('38', 'Neu'),
#   ('分', 'Nf'),
#   ('壓哨', 'VA'),
#   ('拋投', 'VC'),
#   ('絕殺', 'VH'),
#   (' ', 'WHITESPACE'),
#   ('騎士', 'Na'),
#   ('3-0', 'Neu'),
#   ('猛龍', 'Na'),
#   ('拿到', 'VC'),
#   ('賽點', 'Na')],
#  120: [('國腳', 'Na'),
#   ('張呈棟', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('從', 'D'),
#   ('沒', 'D'),
#   ('想', 'VE'),
#   ('過', 'Di'),
#   ('自己', 'Nh'),
#   ('會', 'D'),
#   ('出', 'VC'),
#   ('一', 'Neu'),
#   ('本', 'Nf'),
#   ('書', 'Na')],
#  121: [('離開', 'VC'),
#   ('新疆', 'Nc'),
#   ('的', 'DE'),
#   ('李秋平', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('下', 'Nes'),
#   ('賽季', 'Na'),
#   ('會', 'D'),
#   ('到', 'VCL'),
#   ('哪', 'Nep'),
#   ('個', 'Nf'),
#   ('球隊', 'Na'),
#   ('執教', 'VB'),
#   ('？', 'QUESTIONCATEGORY')],
#  122: [('過人', 'VH'),
#   ('如', 'P'),
#   ('本澤馬', 'Nb'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('卡拉斯科', 'Nb'),
#   ('點贊', 'VA'),
#   ('後', 'Ng'),
#   ('引來', 'VC'),
#   ('馬競', 'Nb'),
#   ('球迷', 'Na'),
#   ('指責', 'VC')],
#  123: [('中國', 'Nc'),
#   ('自己', 'Nh'),
#   ('的', 'DE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('球王', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('：', 'COLONCATEGORY'),
#   ('22', 'Neu'),
#   ('歲', 'Nf'),
#   ('新星', 'Na'),
#   ('戲耍', 'VC'),
#   ('恆大', 'Nb'),
#   ('3', 'Neu'),
#   ('國', 'Nc'),
#   ('腳', 'Na'),
#   ('太', 'Dfa'),
#   ('強悍', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  124: [('曼聯', 'Nb'),
#   ('傳奇', 'Na'),
#   ('主帥', 'Na'),
#   ('弗格森', 'Nb'),
#   ('突發', 'VH'),
#   ('腦溢血', 'VH'),
#   ('入院', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('現在', 'Nd'),
#   ('情況', 'Na'),
#   ('如何', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  125: [('侯森', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('給', 'VD'),
#   ('自己', 'Nh'),
#   ('定位', 'VB'),
#   ('代班門', 'Na'),
#   ('將', 'D'),
#   ('，', 'COMMACATEGORY'),
#   ('等', 'P'),
#   ('楊智', 'Nb'),
#   ('復出', 'VH'),
#   ('國安會', 'Nc'),
#   ('更', 'Dfa'),
#   ('進一步', 'D')],
#  126: [('易', 'Nb'),
#   ('建聯', 'Nb'),
#   ('接班人', 'Na'),
#   ('曬', 'VJ'),
#   ('邀請函', 'Na'),
#   (' 秀', 'FW'),
#   ('警句', 'Na'),
#   ('激勵', 'VC'),
#   ('自己', 'Nh'),
#   ('不忘', 'VK'),
#   ('初心', 'Na')],
#  127: [('西蒙斯', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('我們', 'Nh'),
#   ('涼涼', 'VH'),
#   ('了', 'Di'),
#   ('，0', 'Neu'),
#   ('-', 'DASHCATEGORY'),
#   ('3', 'Neu'),
#   ('沒', 'VJ'),
#   ('希望', 'Na'),
#   ('了', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('球迷', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('你們', 'Nh'),
#   ('需要', 'VK'),
#   ('詹姆斯', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('追', 'VC'),
#   ('吧', 'T')],
#  128: [('丟', 'VC'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('贏', 'VD'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('，', 'COMMACATEGORY'),
#   ('今天', 'Nd'),
#   ('劉詩雯', 'Nb'),
#   ('在', 'P'),
#   ('世乒賽', 'Na'),
#   ('女團', 'Na'),
#   ('決賽', 'Na'),
#   ('的', 'DE'),
#   ('表現', 'Na'),
#   ('值不值得', 'VH'),
#   ('表揚', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  129: [('跑', 'VA'),
#   ('馬拉松', 'Na'),
#   ('你', 'Nh'),
#   ('是', 'SHI'),
#   ('如何', 'D'),
#   ('準備', 'VC'),
#   ('的', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('要', 'D'),
#   ('準備', 'VC'),
#   ('些', 'Nf'),
#   ('什麼', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  130: [('NBA', 'Nb'),
#   ('和', 'Caa'),
#   ('CBA', 'FW'),
#   ('差距', 'Na'),
#   ('在', 'P'),
#   ('哪裡', 'Ncd'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('6', 'Neu'),
#   ('張', 'Nf'),
#   ('圖', 'VF'),
#   ('一目瞭然', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  131: [('上港', 'Nb'),
#   ('主場', 'Na'),
#   ('1-2', 'Neu'),
#   ('負於', 'VJ'),
#   ('國安', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('遭遇', 'VJ'),
#   ('聯賽', 'Na'),
#   ('兩', 'Neu'),
#   ('連敗', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('上港', 'Nb'),
#   ('到底', 'D'),
#   ('輸', 'VD'),
#   ('在', 'P'),
#   ('哪', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  132: [('騎士', 'Na'),
#   ('VS', 'Caa'),
#   ('猛龍', 'Na'),
#   ('G3', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('樂福', 'Nb'),
#   ('在', 'P'),
#   ('內線', 'Na'),
#   ('強硬', 'VH'),
#   ('一', 'Neu'),
#   ('打', 'VC'),
#   ('三', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  133: [('競籃', 'Na'),
#   ('2', 'Neu'),
#   ('串', 'Nf'),
#   ('1', 'Neu'),
#   ('：', 'COLONCATEGORY'),
#   ('勇士', 'Na'),
#   ('客場', 'Na'),
#   ('擒', 'VC'),
#   ('鵜鶘', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('爵士', 'Na'),
#   ('主場', 'Na'),
#   ('再', 'D'),
#   ('負', 'VJ'),
#   ('火箭', 'Na')],
#  134: [('騎', 'VC'),
#   ('士官', 'Na'),
#   ('宣一', 'VC'),
#   ('消息', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('做出', 'VC'),
#   ('回應', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('泰倫盧成', 'Nb'),
#   ('最', 'Dfa'),
#   ('大', 'VH'),
#   ('贏家', 'Na')],
#  135: [('皇馬', 'Nb'),
#   ('2', 'Neu'),
#   ('大', 'VH'),
#   ('鐵', 'Na'),
#   ('主力', 'Na'),
#   ('將', 'D'),
#   ('無緣', 'VH'),
#   ('國家', 'Na'),
#   ('德比', 'Nb')],
#  136: [('這', 'Nep'),
#   ('支', 'Nf'),
#   ('球隊', 'Na'),
#   ('老闆', 'Na'),
#   ('出場', 'VA'),
#   ('踢', 'VC'),
#   ('三', 'Neu'),
#   ('場', 'Nf'),
#   ('足協杯', 'Nb'),
#   ('創', 'VC'),
#   ('歷史', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('球隊', 'Na'),
#   ('三', 'Neu'),
#   ('輪', 'Nf'),
#   ('狂', 'VH'),
#   ('丟', 'VC'),
#   ('14', 'Neu'),
#   ('球', 'Na'),
#   ('也', 'D'),
#   ('創', 'VC'),
#   ('紀錄', 'Na')],
#  137: [('世界', 'Nc'),
#   ('殘疾人', 'Na'),
#   ('射擊', 'Nv'),
#   ('錦標賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('河北', 'Nc'),
#   ('姑娘', 'Na'),
#   ('破', 'VC'),
#   ('世界', 'Nc'),
#   ('紀錄', 'Na'),
#   ('奪冠', 'VA')],
#  138: [('武當', 'Nb'),
#   ('掌門', 'Nc'),
#   ('游玄德', 'Nb'),
#   ('在', 'P'),
#   ('生活', 'Na'),
#   ('中', 'Ng'),
#   ('。', 'PERIODCATEGORY'),
#   ('比如', 'P'),
#   ('街鬥', 'Na'),
#   ('對陣', 'VA'),
#   ('泰拳王西', 'Nb'),
#   ('提猜', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('結果', 'Dk'),
#   ('會', 'D'),
#   ('怎樣', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  139: [('世乒賽', 'Na'),
#   ('男團', 'Na'),
#   ('決賽', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('馬龍', 'Nb'),
#   ('樊振東', 'Nb'),
#   ('許昕', 'Nb'),
#   ('上場', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('奧恰洛夫', 'Nb'),
#   ('受傷', 'VH'),
#   ('德國', 'Nc'),
#   ('無奈', 'VH'),
#   ('變陣', 'VA')],
#  140: [('如何', 'D'),
#   ('看待', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('自由', 'VH'),
#   ('搏擊', 'Na'),
#   ('與', 'Caa'),
#   ('傳統', 'VH'),
#   ('武術', 'Na'),
#   ('誰', 'Nh'),
#   ('厲害', 'VH'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('這樣', 'VH'),
#   ('的', 'DE'),
#   ('問題', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  141: [('2018', 'Nd'),
#   ('瑞典', 'Nc'),
#   ('世乒賽', 'Na'),
#   ('男團', 'Na'),
#   ('半', 'Neqa'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('中國隊', 'Na'),
#   ('3-0', 'Neu'),
#   ('輕鬆', 'VH'),
#   ('取勝', 'VI'),
#   ('，', 'COMMACATEGORY'),
#   ('如何', 'D'),
#   ('評價', 'VC'),
#   ('三', 'Neu'),
#   ('位', 'Nf'),
#   ('球員', 'Na'),
#   ('的', 'DE'),
#   ('表現', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  142: [('2019年', 'Nd'),
#   ('亞洲杯', 'Nb'),
#   ('分組', 'VB'),
#   ('抽籤', 'VA'),
#   ('揭曉', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('中國隊', 'Na'),
#   ('首', 'D'),
#   ('奪', 'VC'),
#   ('亞洲杯', 'Nb'),
#   ('的', 'DE'),
#   ('機會', 'Na'),
#   ('真的', 'D'),
#   ('來', 'VA'),
#   ('了', 'Di'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  143: [('這', 'Nep'),
#   ('一', 'Neu'),
#   ('榜單', 'Na'),
#   ('喬丹', 'Nb'),
#   ('也', 'D'),
#   ('只', 'Da'),
#   ('能', 'D'),
#   ('屈居', 'VG'),
#   ('第二', 'Neu'),
#   (' ', 'WHITESPACE'),
#   ('現役', 'A'),
#   ('季後賽', 'Na'),
#   ('得分榜', 'Na'),
#   ('他', 'Nh'),
#   ('已', 'D'),
#   ('無可', 'D'),
#   ('超越', 'VC')],
#  144: [('爭冠', 'VA'),
#   ('關鍵戰', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('老婦人', 'Na'),
#   ('能否', 'D'),
#   ('主場', 'Na'),
#   ('擒敵', 'VA')],
#  145: [('女排', 'Na'),
#   ('北侖', 'Nc'),
#   ('集訓', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('被', 'P'),
#   ('寄予', 'VD'),
#   ('厚望', 'Na'),
#   ('的', 'DE'),
#   ('小將', 'Na'),
#   ('李盈瑩', 'Nb'),
#   ('正在', 'D'),
#   ('打磨', 'VC'),
#   ('哪些', 'Neqa'),
#   ('技術', 'Na'),
#   ('環節', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  146: [('樂福', 'Nb'),
#   ('頻繁', 'VH'),
#   ('一', 'Neu'),
#   ('打', 'VC'),
#   ('三', 'Neu'),
#   ('稱', 'VG'),
#   ('霸', 'Na'),
#   ('猛龍內線', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('造就', 'VC'),
#   ('詹姆斯', 'Nb'),
#   ('驚世', 'VH'),
#   ('絕殺', 'VA')],
#  147: [('網傳', 'Nb'),
#   ('《', 'PARENTHESISCATEGORY'),
#   ('馬卡報', 'Nb'),
#   ('》', 'PARENTHESISCATEGORY'),
#   ('披露', 'VE'),
#   ('，', 'COMMACATEGORY'),
#   ('內馬爾', 'Nb'),
#   ('希望', 'VK'),
#   ('加盟', 'VC'),
#   ('皇馬', 'Nb'),
#   ('搭檔', 'VA'),
#   ('C', 'FW'),
#   ('羅', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('可能性', 'Na'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('大', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  148: [('主帥', 'Na'),
#   ('1', 'Neu'),
#   ('言', 'Na'),
#   ('恐', 'VK'),
#   ('讓', 'VL'),
#   ('德羅贊', 'Nb'),
#   ('開啓', 'VA'),
#   ('暴走', 'VA'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('2', 'Neu'),
#   ('數據', 'Na'),
#   ('扎心', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('絕境', 'Na'),
#   ('的', 'DE'),
#   ('他', 'Nh'),
#   ('平平無奇', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  149: [('5.5', 'Neu'),
#   ('號', 'Nf'),
#   ('比賽', 'Na'),
#   ('恆大', 'Nb'),
#   ('金英權', 'Nb'),
#   ('解圍', 'VB'),
#   ('踢到', 'VC'),
#   ('球', 'Na'),
#   ('了', 'T'),
#   ('為什麼', 'D'),
#   ('裁判', 'Na'),
#   ('給', 'P'),
#   ('點球', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  150: [('霸氣', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('中國', 'Nc'),
#   ('男隊', 'Na'),
#   ('9-1', 'Neu'),
#   ('擊敗', 'VC'),
#   ('德國', 'Nc'),
#   (' ', 'WHITESPACE'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('王者', 'Na'),
#   ('之', 'DE'),
#   ('師', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('斬獲', 'Na'),
#   ('世乒賽', 'Na'),
#   ('團體', 'Na'),
#   ('九', 'Neu'),
#   ('連冠', 'VA')],
#  151: [('騎士', 'Na'),
#   ('與', 'Caa'),
#   ('猛龍', 'Na'),
#   ('G3', 'FW'),
#   ('，', 'COMMACATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('打板', 'VA'),
#   ('絕殺', 'VC'),
#   ('猛龍', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('球', 'Na'),
#   ('是', 'SHI'),
#   ('什麼', 'Nep'),
#   ('水平', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  152: [('廣州', 'Nc'),
#   ('富力', 'Nb'),
#   ('外援', 'Na'),
#   ('扎哈維', 'Nb'),
#   ('的', 'DE'),
#   ('孩子', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('球場', 'Nc'),
#   ('秀', 'VC'),
#   ('球技', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('頗', 'Dfa'),
#   ('有', 'V_2'),
#   ('老爸', 'Na'),
#   ('的', 'DE'),
#   ('風采', 'Na')],
#  153: [('劉詩雯', 'Nb'),
#   ('在', 'P'),
#   ('世乒賽', 'Na'),
#   ('女團', 'Na'),
#   ('決賽', 'Na'),
#   ('的', 'DE'),
#   ('表現', 'Na'),
#   ('如何', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  154: [('什麼', 'Nep'),
#   ('叫', 'VG'),
#   ('打球', 'VA'),
#   ('要', 'D'),
#   ('用', 'VC'),
#   ('腦', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('看看', 'VE'),
#   ('人家', 'Nh'),
#   ('隆', 'D'),
#   ('指導', 'VC')],
#  155: [('猛', 'Nb'),
#   ('龍主', 'Na'),
#   ('教練', 'Na'),
#   ('跟', 'Caa'),
#   ('泰倫盧', 'Nb'),
#   ('在', 'P'),
#   ('這', 'Nep'),
#   ('個', 'Nf'),
#   ('系列賽', 'Na'),
#   ('的', 'DE'),
#   ('執教', 'VB'),
#   ('水平', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  156: [('身價', 'Na'),
#   ('僅', 'Da'),
#   ('值', 'VJ'),
#   ('300萬', 'Neu'),
#   ('美刀', 'Na'),
#   ('卻', 'D'),
#   ('獲', 'VJ'),
#   ('中超', 'Nb'),
#   ('1億', 'Neu'),
#   ('報價', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('瑞士', 'Nc'),
#   ('巨星', 'Na'),
#   ('嘲諷', 'VC'),
#   ('這', 'Nep'),
#   ('點', 'Nf'),
#   ('錢', 'Na'),
#   ('太少', 'VH'),
#   ('了', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  157: [('天賦', 'Na'),
#   ('超越', 'VC'),
#   ('泰森', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('波蘭', 'Nc'),
#   ('猛將', 'Na'),
#   ('只', 'Da'),
#   ('因', 'P'),
#   ('一', 'Neu'),
#   ('大', 'VH'),
#   ('天生', 'VH'),
#   ('缺陷', 'Na'),
#   ('無緣', 'VH'),
#   ('世界', 'Nc'),
#   ('拳王', 'Na')],
#  158: [('大荔縣', 'Nc'),
#   ('朝邑鎮', 'Nc'),
#   ('：', 'COLONCATEGORY'),
#   ('乘', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('大馬', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('東風', 'Na'),
#   (' 展', 'FW'),
#   ('名鎮', 'Na'),
#   ('風采', 'Na')],
#  159: [('詹姆斯', 'Nb'),
#   ('又', 'D'),
#   ('雙叒叕', 'Na'),
#   ('絕殺', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('洛瑞', 'Nb'),
#   ('直接', 'VH'),
#   ('懵逼', 'VC')],
#  160: [('瑞典', 'Nc'),
#   ('世乒賽', 'Na'),
#   ('男團', 'Na'),
#   ('決賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('中國隊', 'Na'),
#   ('面對', 'VC'),
#   ('德國隊', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('應該', 'D'),
#   ('派出', 'VC'),
#   ('怎麼樣', 'VH'),
#   ('的', 'DE'),
#   ('陣容', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  161: [('真', 'D'),
#   ('急', 'VH'),
#   ('了', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('詹姆斯', 'Nb'),
#   ('與', 'Caa'),
#   ('洛瑞', 'Nb'),
#   ('發生', 'VJ'),
#   ('衝突', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('三', 'Neu'),
#   ('分', 'Nf'),
#   ('回應', 'VC'),
#   ('再現', 'VH'),
#   ('死亡', 'VH'),
#   ('之', 'DE'),
#   ('瞪', 'VC'),
#   ('+', 'FW'),
#   ('絕殺', 'Nv'),
#   ('比賽', 'Na')],
#  162: [('皆大歡喜', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('國乒女隊', 'Na'),
#   ('奪冠', 'VA'),
#   ('後', 'Ng'),
#   ('接受', 'VC'),
#   ('採訪', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('中', 'Ng'),
#   ('肯', 'VL'),
#   ('評價', 'VC'),
#   ('日本', 'Nc'),
#   ('女乒', 'Na'),
#   ('發揮', 'VJ')],
#  163: [('朱婷', 'Nb'),
#   ('受傷', 'VH'),
#   ('下場', 'VA'),
#   ('調整', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('瓦基弗', 'Nb'),
#   ('銀行', 'Nc'),
#   ('差點', 'D'),
#   ('被', 'P'),
#   ('逆轉', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('朱婷', 'Nb'),
#   ('決勝局', 'Na'),
#   ('力輓狂瀾', 'VH')],
#  164: [('國家', 'Na'),
#   ('德比', 'Nb'),
#   ('來襲', 'VA'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('巴薩', 'Nb'),
#   ('力爭', 'VC'),
#   ('勝利', 'VH'),
#   ('送別', 'VC'),
#   ('大師', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('皇馬', 'Nb'),
#   ('卻', 'D'),
#   ('擺出', 'VC'),
#   ('全', 'Neqa'),
#   ('替補', 'VC'),
#   ('陣容', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  165: [('中甲', 'Na'),
#   ('最', 'Dfa'),
#   ('新', 'VH'),
#   ('積分榜', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('梅縣', 'Nc'),
#   ('鐵漢', 'Na'),
#   ('21', 'Neu'),
#   ('分鐘', 'Nf'),
#   ('連', 'D'),
#   ('入', 'VCL'),
#   ('6', 'Neu'),
#   ('球', 'Na'),
#   ('打爆', 'VC'),
#   ('遼寧', 'Nc'),
#   ('宏運', 'Nb'),
#   ('升至', 'VCL'),
#   ('第七', 'Neu')],
#  166: [('奧尼爾', 'Nb'),
#   (':', 'COLONCATEGORY'),
#   ('艾科麥佛鯊', 'Nb'),
#   ('VS', 'FW'),
#   ('維韋杜詹霍', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('誰', 'Nh'),
#   ('是', 'SHI'),
#   ('更', 'Dfa'),
#   ('強戰隊', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  167: [('2019', 'Nd'),
#   ('亞洲杯', 'Nb'),
#   ('中國', 'Nc'),
#   ('國足', 'Na'),
#   ('到底', 'D'),
#   ('怎樣', 'D'),
#   ('做', 'VC'),
#   ('才', 'Da'),
#   ('能', 'D'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('奪冠', 'VA'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('？', 'QUESTIONCATEGORY')],
#  168: [('埃梅里', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('姆巴佩', 'Nb'),
#   ('本來', 'D'),
#   ('想', 'VE'),
#   ('去', 'VCL'),
#   ('皇馬', 'Nb'),
#   ('或', 'Caa'),
#   ('巴薩', 'Nb'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('我', 'Nh'),
#   ('勸住', 'VF'),
#   ('了', 'Di'),
#   ('他', 'Nh')],
#  169: [('亞洲杯', 'Nb'),
#   ('分組', 'VB'),
#   ('國足', 'Na'),
#   ('抽', 'VC'),
#   ('得', 'DE'),
#   ('上', 'VC'),
#   ('上', 'Ncd'),
#   ('簽', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('國足', 'Na'),
#   ('就', 'D'),
#   ('一定', 'D'),
#   ('能', 'D'),
#   ('出線', 'VH'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  170: [('拒絕', 'VF'),
#   ('握手', 'VA'),
#   ('海因克斯 萊萬多夫斯基', 'Nb'),
#   ('究竟', 'D'),
#   ('為', 'VG'),
#   ('何', 'Nes'),
#   ('？', 'QUESTIONCATEGORY')],
#  171: [('NBA', 'Nb'),
#   ('最', 'Dfa'),
#   ('新', 'VH'),
#   ('票價', 'Na'),
#   ('排名', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('勇士隊', 'Nb'),
#   ('第一', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('火箭隊', 'Nb'),
#   ('看', 'VC'),
#   ('了', 'Di'),
#   ('都', 'D'),
#   ('尷尬', 'VH')],
#  172: [('NBA', 'Nb'),
#   ('最', 'Dfa'),
#   ('弱', 'VH'),
#   ('球隊', 'Na'),
#   ('和', 'Caa'),
#   ('CBA', 'FW'),
#   ('最', 'Dfa'),
#   ('強', 'VH'),
#   ('球隊', 'Na'),
#   ('打', 'VC'),
#   ('比賽', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('哪', 'Nep'),
#   ('個', 'Nf'),
#   ('能', 'D'),
#   ('贏', 'VD'),
#   ('？', 'QUESTIONCATEGORY')],
#  173: [('德羅巴', 'Nb'),
#   ('解密', 'VB'),
#   ('助攻', 'VA'),
#   ('秘訣', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('我', 'Nh'),
#   ('喝', 'VC'),
#   ('了', 'Di'),
#   ('球童', 'Na'),
#   ('的', 'DE'),
#   ('聖水', 'Na')],
#  174: [('國足', 'Na'),
#   ('攜手', 'D'),
#   ('傑尼亞', 'Nb'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('里皮', 'Nb'),
#   ('推選', 'VF'),
#   ('3', 'Neu'),
#   ('小將', 'Na'),
#   ('前往', 'VCL'),
#   ('羅馬', 'Nc'),
#   ('訓練', 'VC')],
#  175: [('如何', 'D'),
#   ('在', 'P'),
#   ('商業', 'Na'),
#   ('活動', 'Na'),
#   ('中', 'Ng'),
#   ('不', 'D'),
#   ('受', 'P'),
#   ('人', 'Na'),
#   ('欺騙', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  176: [('瑞典', 'Nc'),
#   ('世乒賽', 'Na'),
#   ('中國', 'Nc'),
#   ('女隊', 'Na'),
#   ('3-1', 'Neu'),
#   ('日本', 'Nc'),
#   ('女隊', 'Na'),
#   ('衛冕', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('如何', 'D'),
#   ('看待', 'VC'),
#   ('劉詩雯', 'Nb'),
#   ('的', 'DE'),
#   ('表現', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  177: [('哈登', 'Nb'),
#   ('和', 'Caa'),
#   ('保羅', 'Nb'),
#   ('激烈', 'VH'),
#   ('爭吵', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('保羅', 'Nb'),
#   ('伸手', 'VA'),
#   ('還', 'D'),
#   ('被', 'P'),
#   ('哈登', 'Nb'),
#   ('打飛', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('安德森', 'Nb'),
#   ('全程', 'D'),
#   ('看呆', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('最後', 'Nd'),
#   ('相互', 'D'),
#   ('不理', 'VJ'),
#   ('，', 'COMMACATEGORY'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  178: [('維特爾', 'Nb'),
#   ('：', 'COLONCATEGORY'),
#   ('近', 'Nes'),
#   ('幾', 'Neu'),
#   ('年', 'Nf'),
#   ('萊科寧', 'Nb'),
#   ('的', 'DE'),
#   ('狀態', 'Na'),
#   ('被', 'P'),
#   ('人們', 'Na'),
#   ('曲解', 'VK'),
#   ('了', 'Di')],
#  179: [('NBA', 'Nb'),
#   ('的', 'DE'),
#   ('三', 'Neu'),
#   ('分', 'Nf'),
#   ('誰', 'Nh'),
#   ('最', 'Dfa'),
#   ('厲害', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  180: [('八', 'Neu'),
#   ('年', 'Nf'),
#   ('抗詹', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('何時', 'Nd'),
#   ('是', 'SHI'),
#   ('頭', 'Na'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('明年', 'Nd'),
#   ('詹姆斯', 'Nb'),
#   ('該', 'D'),
#   ('對', 'P'),
#   ('東部', 'Ncd'),
# ...
#   ('中', 'Ng'),
#   ('的', 'DE'),
#   ('水怪', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('還', 'D'),
#   ('有', 'V_2'),
#   ('美不勝收', 'VH'),
#   ('的', 'DE'),
#   ('自然', 'Na'),
#   ('風景', 'Na')],
#  935: [('雷行記', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('來', 'VA'),
#   ('陝西', 'Nc'),
#   ('旅遊', 'VA'),
#   ('的', 'DE'),
#   ('朋友', 'Na'),
#   ('恭喜', 'VJ'),
#   ('你', 'Nh'),
#   ('，', 'COMMACATEGORY'),
#   ('華山', 'Nc'),
#   ('門票', 'Na'),
#   ('降價', 'VH'),
#   ('了', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  936: [('九月', 'Nd'),
#   ('想', 'VE'),
#   ('自駕', 'VA'),
#   ('去', 'VCL'),
#   ('西藏', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('如果', 'Cbb'),
#   ('我', 'Nh'),
#   ('開車', 'VA'),
#   ('去', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('朋友', 'Na'),
#   ('坐', 'VA'),
#   ('我', 'Nh'),
#   ('的', 'DE'),
#   ('車', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('費用', 'Na'),
#   ('怎麼', 'D'),
#   ('算', 'VE'),
#   ('才', 'Da'),
#   ('合理', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  937: [('廣西', 'Nc'),
#   ('再', 'D'),
#   ('建', 'VC'),
#   ('城際', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('不', 'D'),
#   ('走', 'VA'),
#   ('南寧', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('卻', 'D'),
#   ('連接', 'VJ'),
#   ('了', 'Di'),
#   ('這', 'Nep'),
#   ('兩', 'Neu'),
#   ('個', 'Nf'),
#   ('窮', 'VH'),
#   ('地方', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('1300萬', 'Neu'),
#   ('人', 'Na'),
#   ('將', 'D'),
#   ('脫貧', 'VA'),
#   ('了', 'Di')],
#  938: [('中國', 'Nc'),
#   ('最', 'Dfa'),
#   ('變幻莫測', 'VH'),
#   ('的', 'DE'),
#   ('公路', 'Na'),
#   ('：', 'COLONCATEGORY'),
#   ('積雪', 'VH'),
#   ('比', 'P'),
#   ('車', 'Na'),
#   ('高', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('一會', 'Nd'),
#   ('下雨', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('一會', 'Nd'),
#   ('下雪', 'VA')],
#  939: [('泰山', 'Nc'),
#   ('酒店', 'Nc'),
#   ('都', 'D'),
#   ('不', 'D'),
#   ('便宜', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('20', 'Neu'),
#   ('年', 'Nf'),
#   ('前', 'Ng'),
#   ('都', 'D'),
#   ('100多', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('現在', 'Nd'),
#   ('的', 'DE'),
#   ('價格', 'Na'),
#   ('你', 'Nh'),
#   ('肯定', 'VK'),
#   ('想不到', 'Dk')],
#  940: [('日落', 'VA'),
#   ('霞飛', 'Nc'),
#   ('蒼山', 'Nc'),
#   ('遠', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('求', 'VC'),
#   ('下', 'Nes'),
#   ('句', 'Nf'),
#   ('？', 'QUESTIONCATEGORY')],
#  941: [('茂陵', 'Nc'), ('博物', 'Na'), ('一日', 'Nd'), ('游', 'VA')],
#  942: [('旅遊', 'Nv'),
#   ('風景', 'Na'),
#   ('電腦', 'Na'),
#   ('壁紙', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('適合', 'VH'),
#   ('旅遊', 'VA'),
#   ('的', 'DE'),
#   ('自然', 'Na'),
#   ('風景', 'Na')],
#  943: [('亞洲', 'Nc'),
#   ('地理', 'Na'),
#   ('位置', 'Na'),
#   ('最', 'Dfa'),
#   ('好', 'VH'),
#   ('的', 'DE'),
#   ('國家', 'Na')],
#  944: [('四川', 'Nc'),
#   ('遊客', 'Na'),
#   ('張某', 'Nb'),
#   ('帶', 'VC'),
#   ('著', 'Di'),
#   ('六', 'Neu'),
#   ('名', 'Nf'),
#   ('女子', 'Na'),
#   ('在', 'P'),
#   ('三亞', 'Nc'),
#   ('沙灘', 'Na'),
#   ('燒烤', 'VC'),
#   ('被', 'P'),
#   ('撒沙', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('事', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  945: [('藏南', 'Nc'),
#   ('面積', 'Na'),
#   ('有', 'V_2'),
#   ('多', 'Dfa'),
#   ('長', 'VH'),
#   ('多', 'Dfa'),
#   ('寬', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  946: [('微視頻', 'Na'),
#   ('｜', 'FW'),
#   ('一', 'Neu'),
#   ('分鐘', 'Nf'),
#   ('領略', 'VJ'),
#   ('綿竹', 'Nc'),
#   ('年畫村', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('畫景', 'Na'),
#   ('」', 'PARENTHESISCATEGORY')],
#  947: [('東北', 'Nc'),
#   ('雪鄉', 'Nc'),
#   ('景色', 'Na'),
#   ('美', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('網友', 'Na'),
#   ('稱', 'VE'),
#   ('：', 'COLONCATEGORY'),
#   ('真是', 'D'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('鬥智', 'VA'),
#   ('鬥勇', 'VA'),
#   ('的', 'DE'),
#   ('旅行', 'VA')],
#  948: [('勐景', 'Na'),
#   ('來', 'T'),
#   ('，', 'COMMACATEGORY'),
#   ('在', 'P'),
#   ('拍完', 'VC'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('爸爸', 'Na'),
#   ('去', 'VCL'),
#   ('哪兒', 'Ncd'),
#   ('了', 'Di'),
#   ('3', 'Neu'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('如何', 'D'),
#   ('做到', 'VE'),
#   ('持續', 'VL'),
#   ('吸引', 'VJ'),
#   ('全', 'Neqa'),
#   ('國', 'Nc'),
#   ('遊客', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  949: [('旅行', 'VA'),
#   ('達', 'VJ'),
#   ('人', 'Na'),
#   ('告訴', 'VE'),
#   ('你', 'Nh'),
#   ('，', 'COMMACATEGORY'),
#   ('旅行', 'VA'),
#   ('不管', 'Cbb'),
#   ('短途', 'Na'),
#   ('或是', 'Caa'),
#   ('長途', 'A'),
#   ('別', 'D'),
#   ('忘', 'VK'),
#   ('了', 'Di'),
#   ('帶', 'VC'),
#   ('這些', 'Neqa'),
#   ('，', 'COMMACATEGORY'),
#   ('乾淨', 'VH'),
#   ('還', 'D'),
#   ('衛生', 'VH')],
#  950: [('一', 'Neu'),
#   ('個', 'Nf'),
#   ('人', 'Na'),
#   ('去', 'D'),
#   ('爬山', 'VA'),
#   ('合適', 'VH'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  951: [('發現', 'VE'),
#   ('貴州', 'Nc'),
#   ('之', 'DE'),
#   ('美', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('盡情', 'D'),
#   ('享受', 'VJ'),
#   ('，', 'COMMACATEGORY'),
#   ('難以', 'D'),
#   ('忘懷', 'VJ')],
#  952: [('護照', 'Na'),
#   ('有效期', 'Na'),
#   ('不足', 'VH'),
#   ('6', 'Neu'),
#   ('個', 'Nf'),
#   ('月', 'Na'),
#   ('能', 'D'),
#   ('去', 'VCL'),
#   ('普吉島', 'Nc'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  953: [('四川', 'Nc'),
#   ('遊客', 'Na'),
#   ('張某', 'Nb'),
#   ('帶', 'VC'),
#   ('著', 'Di'),
#   ('六', 'Neu'),
#   ('名', 'Nf'),
#   ('女子', 'Na'),
#   ('在', 'P'),
#   ('三亞', 'Nc'),
#   ('沙灘', 'Na'),
#   ('燒烤', 'VC'),
#   ('被', 'P'),
#   ('撒沙', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('事', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  954: [('重慶', 'Nc'),
#   ('彩色', 'A'),
#   ('馬賽克', 'Na'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('梯田', 'Na'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('吸引', 'VJ'),
#   ('遊人', 'Na')],
#  955: [('五月', 'Nd'),
#   ('冰城', 'Nc'),
#   ('變', 'VG'),
#   ('花海', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('看', 'VC'),
#   ('丁香花叢', 'Na'),
#   ('中', 'Ncd'),
#   ('的', 'DE'),
#   ('哈爾濱', 'Nc')],
#  956: [('想', 'VE'),
#   ('帶', 'VC'),
#   ('二', 'Neu'),
#   ('老', 'Na'),
#   ('去', 'VCL'),
#   ('湖北', 'Nc'),
#   ('遊玩', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('非', 'D'),
#   ('自駕', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('預計', 'VE'),
#   ('花費', 'VC'),
#   ('5000', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('有沒有', 'D'),
#   ('攻略', 'VC'),
#   ('路線', 'Na'),
#   ('推薦', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  957: [('戶外', 'Nc'),
#   ('直播', 'VC'),
#   ('跳舞', 'VA'),
#   ('的', 'DE'),
#   ('爽兒', 'Na'),
#   ('為什麼', 'D'),
#   ('出鏡率', 'Na'),
#   ('那麼', 'D'),
#   ('高', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  958: [('「', 'PARENTHESISCATEGORY'),
#   ('跟著', 'Cbb'),
#   ('大V', 'Na'),
#   ('去', 'D'),
#   ('旅行', 'VA'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('來到', 'VCL'),
#   ('開灤', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('走進', 'VCL'),
#   ('這', 'Nep'),
#   ('座', 'Nf'),
#   ('活', 'VH'),
#   ('著', 'Di'),
#   ('的', 'DE'),
#   ('博物館', 'Nc')],
#  959: [('探秘', 'VA'),
#   ('最後', 'Nd'),
#   ('的', 'DE'),
#   ('香格里拉', 'Nc'),
#   ('之', 'DE'),
#   ('魂', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('縱使', 'Cbb'),
#   ('錯過', 'VJ'),
#   ('全', 'Neqa'),
#   ('世界', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('也', 'D'),
#   ('不', 'D'),
#   ('願意', 'VK'),
#   ('錯過', 'VJ'),
#   ('你', 'Nh')],
#  960: [('平遙', 'Nc'), ('古城', 'Nc'), ('遊記', 'Na')],
#  961: [('去', 'VCL'),
#   ('北海道', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('有', 'V_2'),
#   ('什麼', 'Nep'),
#   ('推薦', 'VC'),
#   ('新奇', 'VH'),
#   ('的', 'DE'),
#   ('溫泉', 'Na'),
#   ('勝地', 'Na'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  962: [('週末', 'Nd'),
#   ('去', 'VCL'),
#   ('哪兒', 'Ncd'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('來', 'VA'),
#   ('安徽', 'Nc'),
#   ('感受', 'VK'),
#   ('國家級', 'Na'),
#   ('絕', 'D'),
#   ('美', 'VH'),
#   ('風景道', 'Nc')],
#  963: [('遠行', 'VA'),
#   ('吧', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('來', 'VA'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('想', 'VE'),
#   ('走', 'VA'),
#   ('就', 'D'),
#   ('走', 'VA'),
#   ('的', 'DE'),
#   ('旅行', 'VA')],
#  964: [('億航', 'Nb'),
#   ('在', 'P'),
#   ('西安', 'Nc'),
#   ('的', 'DE'),
#   ('無', 'VJ'),
#   ('人', 'Na'),
#   ('飛機秀', 'Na'),
#   ('演砸', 'VC'),
#   ('了', 'Di'),
#   ('，', 'COMMACATEGORY'),
#   ('但', 'Cbb'),
#   ('並', 'D'),
#   ('不', 'D'),
#   ('影響', 'VC'),
#   ('繼續', 'VF'),
#   ('它', 'Nh'),
#   ('的', 'DE'),
#   ('表演', 'VC')],
#  965: [('登高', 'VA'),
#   ('投身', 'VC'),
#   ('雲海', 'Na'),
#   ('間', 'Ncd'),
#   ('，', 'COMMACATEGORY'),
#   ('早晨', 'Nd'),
#   ('撫摸', 'VC'),
#   ('陽光', 'Na'),
#   ('炊煙', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('蕩漾湖', 'Nc'),
#   ('上', 'Ncd'),
#   ('與', 'Caa'),
#   ('湖怪', 'Na'),
#   ('嬉戲', 'VA')],
#  966: [('長汀連城', 'Nc'),
#   ('兩', 'Neu'),
#   ('日', 'Nf'),
#   ('游', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('走過', 'VCL'),
#   ('古城', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('探訪', 'VC'),
#   ('培田', 'Nc'),
#   ('古', 'VH'),
#   ('民居', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('登頂', 'VC'),
#   ('冠豸山', 'Nc')],
#  967: [('尼山', 'Nc'),
#   ('聖地', 'Nc'),
#   ('孔子湖', 'Nc'),
#   ('畔', 'Ncd'),
#   ('千', 'Neu'),
#   ('人', 'Na'),
#   ('徒步', 'VA'),
#   (' ', 'WHITESPACE'),
#   ('快樂', 'VH'),
#   ('行走', 'VA'),
#   ('欣賞', 'VJ'),
#   ('尼山', 'Nc'),
#   ('美麗', 'VH'),
#   ('風光', 'Na')],
#  968: [('有', 'V_2'),
#   ('哪些', 'Neqa'),
#   ('日漫', 'Na'),
#   ('中', 'Ng'),
#   ('有', 'V_2'),
#   ('浪漫', 'VH'),
#   ('的', 'DE'),
#   ('櫻花', 'Na'),
#   ('場景', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  969: [('湖北', 'Nc'),
#   ('宜昌', 'Nc'),
#   ('：', 'COLONCATEGORY'),
#   ('最', 'Dfa'),
#   ('浪漫', 'VH'),
#   ('的', 'DE'),
#   ('相親節', 'Nd'),
#   ('在', 'P'),
#   ('薰衣草', 'Na'),
#   ('花海', 'Na'),
#   ('中', 'Ncd'),
#   ('舉行', 'VC'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  970: [('泰山', 'Nb'),
#   ('遊記', 'Na'),
#   ('—', 'DASHCATEGORY'),
#   ('—', 'DASHCATEGORY'),
#   ('一', 'Neu'),
#   ('個', 'Nf'),
#   ('人', 'Na'),
#   ('的', 'DE'),
#   ('自駕', 'VA'),
#   ('之', 'DE'),
#   ('旅', 'Na')],
#  971: [('到', 'P'),
#   ('廣西', 'Nc'),
#   ('旅行', 'VA'),
#   ('這', 'Nep'),
#   ('幾', 'Neu'),
#   ('個', 'Nf'),
#   ('神秘', 'VH'),
#   ('秘境', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('讓', 'VL'),
#   ('人', 'Na'),
#   ('身臨', 'VJ'),
#   ('其中', 'Nep'),
#   ('，', 'COMMACATEGORY'),
#   ('彷彿', 'VG'),
#   ('世界', 'Nc'),
#   ('在', 'P'),
#   ('腳', 'Na'),
#   ('下', 'Ncd')],
#  972: [('為什麼', 'D'),
#   ('許多', 'Neqa'),
#   ('中國人', 'Na'),
#   ('喜好', 'VL'),
#   ('去', 'VCL'),
#   ('泰國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('而', 'Cbb'),
#   ('不', 'D'),
#   ('去', 'VCL'),
#   ('三亞', 'Nc'),
#   ('？', 'QUESTIONCATEGORY')],
#  973: [('五一', 'Neu'),
#   ('小', 'VH'),
#   ('長', 'VH'),
#   ('假', 'VH'),
#   ('首日', 'Nd'),
#   ('：', 'COLONCATEGORY'),
#   ('通道', 'Na'),
#   ('侗寨', 'Nc'),
#   ('遊人', 'Na'),
#   ('如', 'P'),
#   ('織', 'VC')],
#  974: [('靠', 'VJ'),
#   ('花', 'VC'),
#   ('47億', 'Neu'),
#   ('維持', 'VJ'),
#   ('的', 'DE'),
#   ('中國', 'Nc'),
#   ('沙漠', 'Na'),
#   ('第一', 'Neu'),
#   ('湖', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('旺季', 'Nd'),
#   ('門票', 'Na'),
#   ('不下', 'Da'),
#   ('百', 'Neu'),
#   ('元', 'Nf'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  975: [('旅行', 'VA'),
#   ('是', 'SHI'),
#   ('一', 'Neu'),
#   ('種', 'Nf'),
#   ('愛好', 'VL'),
#   ('，', 'COMMACATEGORY'),
#   ('瞭解', 'VK'),
#   ('新鮮', 'VH'),
#   ('的', 'DE'),
#   ('事物', 'Na')],
#  976: [('珠海', 'Nc'),
#   ('國際', 'Nc'),
#   ('會展', 'Na'),
#   ('中心', 'Nc'),
#   ('斬獲', 'Na'),
#   ('行業', 'Na'),
#   ('大獎', 'Na'),
#   (' ', 'WHITESPACE'),
#   ('推動', 'VC'),
#   ('珠海市', 'Nc'),
#   ('會展', 'Na'),
#   ('旅遊', 'VA'),
#   ('產業', 'Na'),
#   ('加快', 'VHC'),
#   ('發展', 'VC')],
#  977: [('貴州省', 'Nc'),
#   ('遵義市', 'Nc'),
#   ('湄潭縣', 'Nc'),
#   ('轄區', 'Nc'),
#   ('內', 'Ncd'),
#   ('旅遊', 'VA'),
#   ('景點', 'Na'),
#   ('簡介', 'Na')],
#  978: [('從', 'P'),
#   ('北京', 'Nc'),
#   ('自駕', 'VA'),
#   ('去', 'VCL'),
#   ('新疆', 'Nc'),
#   ('怎麼', 'D'),
#   ('走', 'VA'),
#   ('合適', 'VH'),
#   ('？', 'QUESTIONCATEGORY')],
#  979: [('「', 'PARENTHESISCATEGORY'),
#   ('東方', 'Ncd'),
#   ('萊茵河', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY'),
#   ('竟然', 'D'),
#   ('藏', 'VC'),
#   ('在', 'P'),
#   ('京郊', 'Nc'),
#   ('這', 'Nep'),
#   ('座', 'Nf'),
#   ('又', 'Caa'),
#   ('大', 'VH'),
#   ('又', 'Caa'),
#   ('美', 'VH'),
#   ('的', 'DE'),
#   ('公園', 'Nc'),
#   ('內', 'Ncd'),
#   ('！', 'EXCLAMATIONCATEGORY'),
#   ('關鍵', 'Na'),
#   ('免費', 'VH'),
#   ('玩', 'VC'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  980: [('一', 'Neu'),
#   ('輩子', 'Na'),
#   ('就', 'D'),
#   ('一', 'Neu'),
#   ('次', 'Nf'),
#   ('的', 'DE'),
#   ('大四', 'Na'),
#   ('畢業', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('該', 'D'),
#   ('選擇', 'VC'),
#   ('旅行', 'VA'),
#   ('還是', 'D'),
#   ('抓緊', 'VC'),
#   ('時間', 'Na'),
#   ('實習', 'VA'),
#   ('？', 'QUESTIONCATEGORY')],
#  981: [('為什麼', 'D'),
#   ('許多', 'Neqa'),
#   ('中國人', 'Na'),
#   ('喜好', 'VL'),
#   ('去', 'VCL'),
#   ('泰國', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('而', 'Cbb'),
#   ('不', 'D'),
#   ('去', 'VCL'),
#   ('三亞', 'Nc'),
#   ('？', 'QUESTIONCATEGORY')],
#  982: [('來文山', 'Nc'),
#   ('玩', 'VC'),
#   ('，', 'COMMACATEGORY'),
#   ('可以', 'D'),
#   ('帶', 'VC'),
#   ('什麼', 'Nep'),
#   ('特產', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  983: [('全', 'Neqa'),
#   ('國', 'Nc'),
#   ('十', 'Neu'),
#   ('大', 'VH'),
#   ('重點', 'Na'),
#   ('產茶縣', 'Nc'),
#   ('之', 'DE'),
#   ('一', 'Neu'),
#   ('「', 'PARENTHESISCATEGORY'),
#   ('壽寧', 'Nc'),
#   ('」', 'PARENTHESISCATEGORY')],
#  984: [('3', 'Neu'),
#   ('個', 'Nf'),
#   ('月', 'Na'),
#   ('貢獻', 'VC'),
#   ('392億', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('中國', 'Nc'),
#   ('遊客', 'Na'),
#   ('去', 'VCL'),
#   ('日本', 'Nc'),
#   ('卻', 'D'),
#   ('不', 'D'),
#   ('為', 'P'),
#   ('旅遊', 'VA'),
#   ('觀光', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('到底', 'D'),
#   ('為', 'VJ'),
#   ('的', 'DE'),
#   ('什麼', 'Nep'),
#   ('？', 'QUESTIONCATEGORY')],
#  985: [('全', 'Neqa'),
#   ('國', 'Nc'),
#   ('這', 'Nep'),
#   ('8', 'Neu'),
#   ('個', 'Nf'),
#   ('5A', 'FW'),
#   ('級別', 'Na'),
#   ('的', 'DE'),
#   ('旅遊', 'Nv'),
#   ('古', 'VH'),
#   ('城鎮', 'Nc'),
#   ('，', 'COMMACATEGORY'),
#   ('你', 'Nh'),
#   ('去', 'VCL'),
#   ('過', 'Di'),
#   ('幾', 'Neu'),
#   ('個', 'Nf'),
#   ('？', 'QUESTIONCATEGORY')],
#  986: [('南寧', 'Nc'),
#   ('城市', 'Na'),
#   ('怎麼樣', 'VH'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('適合', 'VH'),
#   ('東北人', 'Na'),
#   ('生活', 'Na'),
#   ('嗎', 'T'),
#   ('？', 'QUESTIONCATEGORY')],
#  987: [('這', 'Nep'),
#   ('就', 'D'),
#   ('是', 'SHI'),
#   ('西藏', 'Nc'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  988: [('除', 'P'),
#   ('一些', 'Neqa'),
#   ('必備', 'A'),
#   ('物品', 'Na'),
#   ('外', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('旅行', 'VA'),
#   ('時', 'Ng'),
#   ('還', 'D'),
#   ('有', 'V_2'),
#   ('哪些', 'Neqa'),
#   ('省', 'Nc'),
#   ('空間', 'Na'),
#   ('少', 'VH'),
#   ('重量', 'Na'),
#   ('又', 'D'),
#   ('實用', 'VH'),
#   ('的', 'DE'),
#   ('東西', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  989: [('貴州', 'Nc'),
#   ('六', 'Neu'),
#   ('盤', 'Nf'),
#   ('水', 'Na'),
#   ('的', 'DE'),
#   ('這', 'Nep'),
#   ('幾', 'Neu'),
#   ('個', 'Nf'),
#   ('景點', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('錯過', 'VJ'),
#   ('一', 'Neu'),
#   ('個', 'Nf'),
#   ('你', 'Nh'),
#   ('都', 'D'),
#   ('會', 'D'),
#   ('覺得', 'VK'),
#   ('可惜', 'VH'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  990: [('他們', 'Nh'),
#   ('將', 'P'),
#   ('家', 'Nc'),
#   ('豬', 'Na'),
#   ('丟棄', 'VC'),
#   ('在', 'P'),
#   ('無', 'VJ'),
#   ('人', 'Na'),
#   ('島', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('幾', 'Neu'),
#   ('年', 'Nf'),
#   ('之後', 'Ng'),
#   ('，', 'COMMACATEGORY'),
#   ('它們', 'Nh'),
#   ('的', 'DE'),
#   ('生活', 'Na'),
#   ('竟是', 'VG'),
#   ('這樣', 'VH'),
#   ('的', 'T'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  991: [('來', 'VA'),
#   ('四川', 'Nc'),
#   ('旅遊', 'VA'),
#   ('必', 'D'),
#   ('去', 'VCL'),
#   ('的', 'DE'),
#   ('八', 'Neu'),
#   ('大', 'VH'),
#   ('景點', 'Na')],
#  992: [('千姿百色', 'Na'),
#   ('弄', 'VC'),
#   ('秋光', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('求', 'VC'),
#   ('對', 'VC'),
#   ('子', 'Na'),
#   ('？', 'QUESTIONCATEGORY')],
#  993: [('為什麼', 'D'),
#   ('要', 'D'),
#   ('來', 'VA'),
#   ('這裡', 'Ncd'),
#   ('看', 'VC'),
#   ('映山紅', 'Na'),
#   ('？', 'QUESTIONCATEGORY'),
#   ('北京', 'Nc'),
#   ('這', 'Nep'),
#   ('處', 'Nf'),
#   ('抗戰', 'Nv'),
#   ('聖地', 'Nc'),
#   ('有', 'V_2'),
#   ('著', 'Di'),
#   ('悲壯', 'VH'),
#   ('的', 'DE'),
#   ('經歷', 'Nv')],
#  994: [('來', 'VA'),
#   ('一', 'Neu'),
#   ('場', 'Nf'),
#   ('說', 'VE'),
#   ('走', 'VA'),
#   ('就', 'D'),
#   ('走', 'VA'),
#   ('的', 'DE'),
#   ('旅行', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('陝西', 'Nc'),
#   ('寶雞', 'Nc'),
#   ('紅河谷', 'Nc'),
#   ('走起', 'VA')],
#  995: [('四川', 'Nc'),
#   ('遊客', 'Na'),
#   ('張某', 'Nb'),
#   ('帶', 'VC'),
#   ('著', 'Di'),
#   ('六', 'Neu'),
#   ('名', 'Nf'),
#   ('女子', 'Na'),
#   ('在', 'P'),
#   ('三亞', 'Nc'),
#   ('沙灘', 'Na'),
#   ('燒烤', 'VC'),
#   ('被', 'P'),
#   ('撒沙', 'VA'),
#   ('，', 'COMMACATEGORY'),
#   ('這', 'Nep'),
#   ('事', 'Na'),
#   ('你', 'Nh'),
#   ('怎麼', 'D'),
#   ('看', 'VC'),
#   ('？', 'QUESTIONCATEGORY')],
#  996: [('農村', 'Nc'),
#   ('集市', 'Nc'),
#   ('上', 'Ncd'),
#   ('這些', 'Neqa'),
#   ('的', 'DE'),
#   ('東西', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('真的', 'D'),
#   ('是', 'SHI'),
#   ('便宜', 'VH'),
#   ('又', 'Caa'),
#   ('好吃', 'VH'),
#   ('，', 'COMMACATEGORY'),
#   ('簡直', 'D'),
#   ('賺', 'VC'),
#   ('大', 'VH'),
#   ('了', 'T')],
#  997: [('全', 'Neqa'),
#   ('世界', 'Nc'),
#   ('最', 'Dfa'),
#   ('出名', 'VH'),
#   ('的', 'DE'),
#   ('貓', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('它', 'Nh'),
#   ('數', 'VC'),
#   ('第二', 'Neu'),
#   ('，', 'COMMACATEGORY'),
#   ('沒', 'VJ'),
#   ('人', 'Na'),
#   ('敢', 'VL'),
#   ('數', 'VC'),
#   ('第一', 'Neu'),
#   ('了', 'T'),
#   ('吧', 'T')],
#  998: [('易縣', 'Nc'),
#   ('最', 'Dfa'),
#   ('美', 'VH'),
#   ('的', 'DE'),
#   ('五月', 'Nd'),
#   ('，', 'COMMACATEGORY'),
#   ('藍色', 'Na'),
#   ('油菜花', 'Na'),
#   ('開好', 'VC'),
#   ('了', 'Di')],
#  999: [('千', 'Neu'),
#   ('人', 'Na'),
#   ('相親', 'VA'),
#   ('大會', 'Na'),
#   ('，', 'COMMACATEGORY'),
#   ('單身', 'VH'),
#   ('的', 'DE'),
#   ('有', 'V_2'),
#   ('福利', 'Na'),
#   ('來', 'VA'),
#   ('了', 'Di'),
#   ('！', 'EXCLAMATIONCATEGORY')],
#  ...}

# %%
word2index = {}
index2word = {}
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n 
        index2word[n] = word
        n += 1

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %%
train_bow_vectors = {
    index: get_bow_vector_with_selection(pairs, word2index)
    for index, pairs in train_title_cuts.items()
}

test_bow_vectors = {
    index: get_bow_vector_with_selection(pairs, word2index)
    for index, pairs in test_title_cuts.items()
}

# %%
print(len(test_bow_vectors))
# Out:
# 600

# %% [markdown]
# # TFIDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
train_index_array, train_vector_array = list(zip(*train_bow_vectors.items()))
print(train_vector_array)
# Out:
# (array([1., 1., 1., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 2., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([1., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([1., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([1., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([1., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([1., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0. ...

# %%
# unpacking operator *
train_index_array, train_vector_array = list(zip(*train_bow_vectors.items()))

# 使用`TfidfTransformer`來將`train_vector_array`轉換成`train_tfidf_vector_array`
#########################
transformer=TfidfTransformer() 
train_tfidf_vector_array= transformer.fit_transform(train_vector_array)

# %%
train_tfidf_vector_array
# Out:
# <1800x6690 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17126 stored elements in Compressed Sparse Row format>

# %%
type(train_tfidf_vector_array)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
vector = train_tfidf_vector_array.getrow(0).toarray()
print(vector)
# Out:
# [[0.2785649  0.32947575 0.36159692 ... 0.         0.         0.        ]]

# %%
print(train_tfidf_vector_array.toarray().shape)
# Out:
# (1800, 6690)

# %%
train_tfidf_vectors = {}
# https://stackoverflow.com/questions/35109424/how-to-make-tf-idf-matrix-dense
for i, index in enumerate(train_index_array):
    # https://www.kite.com/python/docs/scipy.sparse.bsr_matrix.getrow
    vector = train_tfidf_vector_array.getrow(i).toarray()[0]
    train_tfidf_vectors[index] = vector

# %%
train_tfidf_vectors[120]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
test_index_array, test_vector_array = list(zip(*test_bow_vectors.items()))

# 使用同一個`TfidfTransformer`來轉換testing dataset
transformer=TfidfTransformer() 
test_tfidf_vector_array= transformer.fit_transform(test_vector_array)

# %%
vector = test_tfidf_vector_array.getrow(0).toarray()
print(vector)
# Out:
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
test_tfidf_vectors = {}
for i, index in enumerate(test_index_array):
    vector = test_tfidf_vector_array.getrow(i).toarray()[0]
    test_tfidf_vectors[index] = vector

# %%
print(len(test_tfidf_vectors))
# Out:
# 600

# %% [markdown]
# # TFIDF + Group mean vector: 測試

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, vector in sorted(train_tfidf_vectors.items()):
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00171764, 0.00152024,
#         0.00152024]),
#  '體育': array([0.01151249, 0.00394476, 0.00120532, ..., 0.        , 0.        ,
#         0.        ])}

# %%
def cosine_similarity(bow1, bow2):
    len_bow1 = np.sqrt(np.sum(np.square(bow1)))
    len_bow2 = np.sqrt(np.sum(np.square(bow2)))
    return np.sum(bow1 * bow2) / (len_bow1 * len_bow2)

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, vector in sorted(test_tfidf_vectors.items()):
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 83, '遊戲': 7, '財經': 6, '旅遊': 6, '科技': 3, '農業': 3})
# predict 財經 :  Counter({'財經': 76, '科技': 14, '旅遊': 6, '農業': 6, '體育': 4, '遊戲': 2})
# predict 科技 :  Counter({'科技': 66, '財經': 11, '農業': 6, '體育': 3, '遊戲': 3, '旅遊': 1})
# predict 旅遊 :  Counter({'旅遊': 78, '農業': 10, '科技': 5, '財經': 3, '遊戲': 1})
# predict 農業 :  Counter({'農業': 74, '旅遊': 7, '科技': 6, '體育': 4, '財經': 2, '遊戲': 1})
# predict 遊戲 :  Counter({'遊戲': 86, '科技': 5, '體育': 4, '財經': 2})

# %% [markdown]
# # Visualization

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, svd_solver='full')

anchor_classes, anchor_vectors = list(zip(*group_mean_vector.items()))
# 為了看清楚Group Mean Vector怎麼幫助我們做分類問題，我們針對Group Mean Vector (anchor) 來進行PCA降維
pca.fit(anchor_vectors)
reduced_anchor_vectors = pca.transform(anchor_vectors)
reduced_test_tfidf_vector_array = pca.transform(test_tfidf_vector_array.toarray())

# %%
reduced_test_tfidf_vector_array
# Out:
# array([[-0.02447703, -0.0318951 ],
#        [ 0.03662089, -0.08792716],
#        [-0.02693275, -0.04781636],
#        ...,
#        [ 0.04506187, -0.05394296],
#        [ 0.10487201, -0.04521801],
#        [ 0.03227716, -0.03324108]])

# %%
import matplotlib
import matplotlib.pyplot as plt

#https://numpy.org/doc/stable/reference/generated/numpy.vectorize.html
test_class_array = np.vectorize(test_classes.get)(test_index_array)

label_mapping = {
    '體育': 'sport',
    '財經': 'financial',
    '科技': 'tech',
    '旅遊': 'travel',
    '農業': 'agriculture',
    '遊戲': 'game'
}

plt.figure(figsize=(8, 8))
for real_class in all_news_class:
    plt.scatter(reduced_test_tfidf_vector_array[test_class_array == real_class, 0],
                reduced_test_tfidf_vector_array[test_class_array == real_class, 1],
                label=label_mapping[real_class],
                alpha=0.3)
    # https://www.runoob.com/python/att-list-index.html
    i = anchor_classes.index(real_class)
    plt.plot([0, reduced_anchor_vectors[i, 0]], [0, reduced_anchor_vectors[i, 1]])
plt.legend(loc="best", shadow=False, scatterpoints=1)

plt.show()

# %%
np.vectorize(test_classes.get)

# %%
print(test_classes.get)
# Out:
# <built-in method get of dict object at 0x7f05bc47d3a8>
